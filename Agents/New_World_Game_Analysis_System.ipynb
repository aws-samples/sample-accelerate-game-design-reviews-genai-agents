# %% [markdown]
# # New World Game Analyst Powered By Amazon Bedrock AgentCore
#
# This notebook combines the functionality of the New World Game Analysis System, which includes specialized AI agents for analyzing game design documents and providing expert feedback about Amazon Game Studios' MMORPG "New World".
#
# # System Overview
#
# 1. **Game Analyst Agent**: Main orchestrating agent that coordinates between specialized agents
# 2. **Lore Agent**: Specializes in game world, history, and narrative elements
# 3. **Gameplay Agent**: Focuses on game mechanics, systems, and player engagement
# 4. **Corporate Strategy Agent**: Focuses on company strategy and roadmaps
# 5. **QA Agent**: Focuses on player behavioral data and other in game data

# %% [markdown]
# # Data Sources

# %% [markdown]
# - Go over knowledge bases and breif on how they were set up and why you need them

# %% [markdown]
# # Prerequisites
# - Python 3.10+
# - AWS Credentials
# - Amazon Bedrock AgentCore SDK
# - Strands Agents

# %%
# Install required packages
# !uv add -r requirements.txt --active
# Out:
# Running cells with 'Python 3.14.0' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ## Load Credentials

# %%
from dotenv import load_dotenv
import os

load_dotenv()
AWS_PROFILE = os.getenv("AWS_PROFILE")
print(AWS_PROFILE)
# Out:
# default

# %% [markdown]
# # Lets build some simple agents

# %% [markdown]
# ## Create Agent Roles

# %% [markdown]
# Create basic agent IAM roles with all permissions needed for the agents to be configured, launched, use tools such as knowledge bases, and invoke other agents

# %%
from utils import create_agentcore_role
import os
import string
import random

def generate_random_suffix(length=6):
    return ''.join(random.choices(string.ascii_lowercase + string.digits, k=length))

gameplay_agent_name = f"gameplay_agent_{generate_random_suffix()}"
gameplay_iam_role = create_agentcore_role(agent_name=gameplay_agent_name, region=os.getenv("AWS_REGION"))
gameplay_role_arn = gameplay_iam_role['Role']['Arn']
gameplay_role_name = gameplay_iam_role['Role']['RoleName']
print(gameplay_role_arn)
print(gameplay_role_name)

lore_agent_name = f"lore_agent_{generate_random_suffix()}"
lore_agent_iam_role = create_agentcore_role(agent_name=lore_agent_name, region=os.getenv("AWS_REGION"))
lore_agent_role_arn = lore_agent_iam_role['Role']['Arn']
lore_agent_role_name = lore_agent_iam_role['Role']['RoleName']
print(lore_agent_role_arn)
print(lore_agent_role_name)

game_analyst_agent_name = f"game_analyst_agent_{generate_random_suffix()}"
game_analyst_iam_role = create_agentcore_role(agent_name=game_analyst_agent_name, region=os.getenv("AWS_REGION"))
game_analyst_role_arn = game_analyst_iam_role['Role']['Arn']
game_analyst_role_name = game_analyst_iam_role['Role']['RoleName']
print(game_analyst_iam_role)
print(game_analyst_role_arn)
print(game_analyst_role_name)

strategy_agent_name = f"strategy_agent_{generate_random_suffix()}"
strategy_iam_role = create_agentcore_role(agent_name=strategy_agent_name, region=os.getenv("AWS_REGION"))
strategy_role_arn = strategy_iam_role['Role']['Arn']
strategy_role_name = strategy_iam_role['Role']['RoleName']
print(strategy_iam_role)
print(strategy_role_arn)
print(strategy_role_name)
# Out:
# attaching role policy agentcore-gameplay_agent_gbpz6w-role
# arn:aws:iam::582048091268:role/agentcore-gameplay_agent_gbpz6w-role
# agentcore-gameplay_agent_gbpz6w-role
# attaching role policy agentcore-lore_agent_piscxw-role
# arn:aws:iam::582048091268:role/agentcore-lore_agent_piscxw-role
# agentcore-lore_agent_piscxw-role
# attaching role policy agentcore-game_analyst_agent_fm2dr4-role
# {'Role': {'Path': '/', 'RoleName': 'agentcore-game_analyst_agent_fm2dr4-role', 'RoleId': 'AROAYPBGFBSCMHP7RYLDV', 'Arn': 'arn:aws:iam::582048091268:role/agentcore-game_analyst_agent_fm2dr4-role', 'CreateDate': datetime.datetime(2025, 11, 21, 17, 1, 6, tzinfo=tzutc()), 'AssumeRolePolicyDocument': {'Version': '2012-10-17', 'Statement': [{'Sid': 'AssumeRolePolicy', 'Effect': 'Allow', 'Principal': {'Service': 'bedrock-agentcore.amazonaws.com'}, 'Action': 'sts:AssumeRole', 'Condition': {'StringEquals': {'aws:SourceAccount': '582048091268'}, 'ArnLike': {'aws:SourceArn': 'arn:aws:bedrock-agentcore:us-west-2:582048091268:*'}}}]}}, 'ResponseMetadata': {'RequestId': '08e264c8-9bf6-4502-a89d-52b51f3dc02f', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Fri, 21 Nov 2025 17:01:06 GMT', 'x-amzn-requestid': '08e264c8-9bf6-4502-a89d-52b51f3dc02f', 'content-type': 'text/xml', 'content-length': '1126'}, 'RetryAttempts': 0}}
# arn:aws:iam::582048091268:role/agentcore-game_analyst_agent_fm2dr4-role
# agentcore-game_analyst_agent_fm2dr4-role
# attaching role policy agentcore-strategy_agent_8zvhvo-role
# {'Role': {'Path': '/', 'RoleName': 'agentcore-strategy_agent_8zvhvo-role', 'RoleId': 'AROAYPBGFBSCLUOZUVSIM', 'Arn': 'arn:aws:iam::582048091268:role/agentcore-strategy_agent_8zvhvo-role', 'CreateDate': datetime.datetime(2025, 11, 21, 17, 1, 17, tzinfo=tzutc()), 'AssumeRolePolicyDocument': {'Version': '2012-10-17', 'Statement': [{'Sid': 'AssumeRolePolicy', 'Effect': 'Allow', 'Principal': {'Service': 'bedrock-agentcore.amazonaws.com'}, 'Action': 'sts:AssumeRole', 'Condition': {'StringEquals': {'aws:SourceAccount': '582048091268'}, 'ArnLike': {'aws:SourceArn': 'arn:aws:bedrock-agentcore:us-west-2:582048091268:*'}}}]}}, 'ResponseMetadata': {'RequestId': '64eabaf5-cb9f-4466-a714-469e6063f7da', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Fri, 21 Nov 2025 17:01:17 GMT', 'x-amzn-requestid': '64eabaf5-cb9f-4466-a714-469e6063f7da', 'content-type': 'text/xml', 'content-length': '1118'}, 'RetryAttempts': 0}}
# arn:aws:iam::582048091268:role/agentcore-strategy_agent_8zvhvo-role
# agentcore-strategy_agent_8zvhvo-role

# %% [markdown]
# ## Runtime Configuration

# %% [markdown]
# Helper function for configuring and launching AgentCore agent runtimes

# %%
from bedrock_agentcore_starter_toolkit import Runtime
from boto3.session import Session
import time


def configure_runtime(agent_name, agentcore_iam_role, python_file_name):
    boto_session = Session(region_name=os.getenv("AWS_REGION"))
    region = boto_session.region_name

    agentcore_runtime = Runtime()

    response = agentcore_runtime.configure(
        entrypoint=python_file_name,
        execution_role=agentcore_iam_role['Role']['Arn'],
        auto_create_ecr=True,
        requirements_file="requirements.txt",
        region=region,
        agent_name=agent_name
    )
    return response, agentcore_runtime

def check_status(agent_runtime):
    status_response = agent_runtime.status()
    status = status_response.endpoint['status']
    end_status = ['READY', 'CREATE_FAILED', 'DELETE_FAILED', 'UPDATE_FAILED']
    while status not in end_status:
        time.sleep(10)
        status_response = agent_runtime.status()
        status = status_response.endpoint['status']
        print(status)
    return status

# %%
# set the current working directory to be the gameplay-agent folder
import os
#os.chdir('../gameplay-agent')
os.chdir('./../gameplay-agent-basic')
print(os.getcwd())
# Out:
# /Users/sampatze/Documents/Projects/gitlab/accelerate-game-design-reviews-genai-agents/Agents/basic-strands-agents/gameplay-agent-basic

# %% [markdown]
# ## Create Gameplay Agent

# %%
# %%writefile gameplay_agent.py


import argparse
import json
from mcp import StdioServerParameters, stdio_client
from strands import Agent, tool
from strands.models import BedrockModel
from strands.tools.mcp import MCPClient
from bedrock_agentcore.runtime import BedrockAgentCoreApp

###########################
# MCP Clients             #
###########################

# Tool: Knowledge Base MCP Client
kb_client = MCPClient(
    lambda: stdio_client(
        StdioServerParameters(
            command="uvx", 
            args=["awslabs.bedrock-kb-retrieval-mcp-server@latest"],
            env={
                "BEDROCK_KB_RERANKING_ENABLED": "true",
                "KB_INCLUSION_TAG_KEY": "new-world-design-docs"
            }
        )

    )
)

# Model: Configure Bedrock model
bedrock_model = BedrockModel(
    model_id="global.anthropic.claude-sonnet-4-5-20250929-v1:0",
    temperature=0.3,
)


# Prompt: System prompt for the Gameplay agent
GAMEPLAY_AGENT_PROMPT = """
You are a New World Gameplay Expert specializing in all gameplay mechanics for New World built by Amazon Game Studios. Your expertise includes:
- Character attributes and weapon scaling (Strength, Dexterity, Intelligence, Focus)
- Crafting systems (Armoring, Weaponsmithing, Arcana, Cooking, etc.)
- Gathering and refining (Mining, Logging, Harvesting, Fishing, Skinning)
- Territory control and faction systems (Covenant, Marauders, Syndicate)
- Expeditions and PvE content
- Game mechanics and optimization strategies

ALWAYS use the available knowledge base tools to retrieve information before answering questions. If the knowledge base returns relevant information, use that information in your response.

When using knowledge base tools, make sure to:
1. Use the exact query or related terms to search the knowledge base
2. Include the retrieved information in your response
3. Only use information from the knowledge base
4. Provide practical gameplay advice based on the retrieved data
"""


app = BedrockAgentCoreApp()


# Create and run the Gameplay agent
@app.entrypoint
def gameplay_agent(payload):
    """
    Creates and runs a gameplay agent connected to the New World Knowledge Base
    """

    try:
        with kb_client:
            # Get tools from the KB client
            kb_tools = kb_client.list_tools_sync()

            # Agent: Create the gameplay agent
            agent = Agent(
                tools=kb_tools,
                model=bedrock_model,
                system_prompt=GAMEPLAY_AGENT_PROMPT
            )

            user_input = payload.get("prompt")
            print("User input:", user_input)
            response = agent(user_input)
            if (len(response.message['content'][0]['text']) > 100):
                print(response.message['content'][0]['text'])
                return response.message['content'][0]['text']

    except Exception as e:
        print(f"Error accessing Knowledge Base: {e}")
        return f"error {e}"

if __name__ == "__main__":
    app.run()
# Out:
# Overwriting gameplay_agent.py

# %% [markdown]
# ### Launch the gameplay agent runtime

# %%
_, gameplay_agentcore_runtime = configure_runtime("gameplay_agent_no_memory", gameplay_iam_role, "gameplay_agent.py")
gameplay_launch_result = gameplay_agentcore_runtime.launch(auto_update_on_conflict="true")
gameplay_agent_id = gameplay_launch_result.agent_id
gameplay_agent_arn = gameplay_launch_result.agent_arn

print(gameplay_agent_arn)
# Out:
# Entrypoint parsed: file=/Users/sampatze/Documents/Projects/gitlab/accelerate-game-design-reviews-genai-agents/Agents/basic-strands-agents/gameplay-agent-basic/gameplay_agent.py, bedrock_agentcore_name=gameplay_agent
# Memory disabled - agent will be stateless
# Configuring BedrockAgentCore agent: gameplay_agent_no_memory
# Memory disabled
# Network mode: PUBLIC
# Generated Dockerfile: Dockerfile
# Generated .dockerignore: /Users/sampatze/Documents/Projects/gitlab/accelerate-game-design-reviews-genai-agents/Agents/basic-strands-agents/gameplay-agent-basic/.dockerignore
# Keeping 'gameplay_agent_no_memory' as default agent
# Bedrock AgentCore configured: /Users/sampatze/Documents/Projects/gitlab/accelerate-game-design-reviews-genai-agents/Agents/basic-strands-agents/gameplay-agent-basic/.bedrock_agentcore.yaml
# 🚀 Launching Bedrock AgentCore (cloud mode - RECOMMENDED)...
#    • Deploy Python code directly to runtime
#    • No Docker required (DEFAULT behavior)
#    • Production-ready deployment
#
# 💡 Deployment options:
#    • runtime.launch()                → Cloud (current)
#    • runtime.launch(local=True)      → Local development
# Memory disabled - skipping memory creation
# Starting CodeBuild ARM64 deployment for agent 'gameplay_agent_no_memory' to account 582048091268 (us-west-2)
# Setting up AWS resources (ECR repository, execution roles)...
# Getting or creating ECR repository for agent: gameplay_agent_no_memory
# ECR repository available: 582048091268.dkr.ecr.us-west-2.amazonaws.com/bedrock-agentcore-gameplay_agent_no_memory
# Using execution role from config: arn:aws:iam::582048091268:role/agentcore-gameplay_agent_gbpz6w-role
# Preparing CodeBuild project and uploading source...
# ✅ Reusing existing ECR repository: 582048091268.dkr.ecr.us-west-2.amazonaws.com/bedrock-agentcore-gameplay_agent_no_memory
# Getting or creating CodeBuild execution role for agent: gameplay_agent_no_memory
# Role name: AmazonBedrockAgentCoreSDKCodeBuild-us-west-2-0db070ebee
# Reusing existing CodeBuild execution role: arn:aws:iam::582048091268:role/AmazonBedrockAgentCoreSDKCodeBuild-us-west-2-0db070ebee
# Using dockerignore.template with 43 patterns for zip filtering
# Uploaded source to S3: gameplay_agent_no_memory/source.zip
# Updated CodeBuild project: bedrock-agentcore-gameplay_agent_no_memory-builder
# Starting CodeBuild build (this may take several minutes)...
# Starting CodeBuild monitoring...
# 🔄 QUEUED started (total: 0s)
# ✅ QUEUED completed in 1.1s
# 🔄 PROVISIONING started (total: 1s)
# ✅ PROVISIONING completed in 7.4s
# 🔄 DOWNLOAD_SOURCE started (total: 9s)
# ✅ DOWNLOAD_SOURCE completed in 1.1s
# 🔄 BUILD started (total: 10s)
# ✅ BUILD completed in 18.1s
# 🔄 POST_BUILD started (total: 28s)
# ✅ POST_BUILD completed in 12.8s
# 🔄 COMPLETED started (total: 41s)
# ✅ COMPLETED completed in 1.1s
# 🎉 CodeBuild completed successfully in 0m 41s
# CodeBuild completed successfully
# CodeBuild project configuration saved
# Deploying to Bedrock AgentCore...
# Agent created/updated: arn:aws:bedrock-agentcore:us-west-2:582048091268:runtime/gameplay_agent_no_memory-r7wRmg619p
# Observability is enabled, configuring Transaction Search...
# CloudWatch Logs resource policy already configured
# X-Ray trace destination already configured
# X-Ray indexing rule already configured
# Transaction Search already fully configured
# 🔍 GenAI Observability Dashboard:
#    https://console.aws.amazon.com/cloudwatch/home?region=us-west-2#gen-ai-observability/agent-core
# Polling for endpoint to be ready...
# Agent endpoint: arn:aws:bedrock-agentcore:us-west-2:582048091268:runtime/gameplay_agent_no_memory-r7wRmg619p/runtime-endpoint/DEFAULT
# Deployment completed successfully - Agent: arn:aws:bedrock-agentcore:us-west-2:582048091268:runtime/gameplay_agent_no_memory-r7wRmg619p
# Built with CodeBuild: bedrock-agentcore-gameplay_agent_no_memory-builder:19122f47-23d4-4274-9685-57410b795a94
# Deployed to cloud: arn:aws:bedrock-agentcore:us-west-2:582048091268:runtime/gameplay_agent_no_memory-r7wRmg619p
# ECR image: 582048091268.dkr.ecr.us-west-2.amazonaws.com/bedrock-agentcore-gameplay_agent_no_memory
# 🔍 Agent logs available at:
#    /aws/bedrock-agentcore/runtimes/gameplay_agent_no_memory-r7wRmg619p-DEFAULT --log-stream-name-prefix "2025/11/23/\[runtime-logs]"
#    /aws/bedrock-agentcore/runtimes/gameplay_agent_no_memory-r7wRmg619p-DEFAULT --log-stream-names "otel-rt-logs"
# 💡 Tail logs with: aws logs tail /aws/bedrock-agentcore/runtimes/gameplay_agent_no_memory-r7wRmg619p-DEFAULT --log-stream-name-prefix "2025/11/23/\[runtime-logs]" --follow
# 💡 Or view recent logs: aws logs tail /aws/bedrock-agentcore/runtimes/gameplay_agent_no_memory-r7wRmg619p-DEFAULT --log-stream-name-prefix "2025/11/23/\[runtime-logs]" --since 1h
# arn:aws:bedrock-agentcore:us-west-2:582048091268:runtime/gameplay_agent_no_memory-r7wRmg619p

# %% [markdown]
# ### Save the gameplay agent ARN to AWS SSM ParameterStore

# %%
import boto3
import time

ssm = boto3.client('ssm')
ssm.put_parameter(
    Name=f'/agents/gameplay_agent_arn_no_memories',
    Value=gameplay_agent_arn,
    Type='String',
    Overwrite=True
)
# Out:
# {'Version': 1,
#  'Tier': 'Standard',
#  'ResponseMetadata': {'RequestId': 'dd21d610-1bb4-465b-b78b-c42bc21023d5',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'server': 'Server',
#    'date': 'Fri, 21 Nov 2025 17:09:10 GMT',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '31',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': 'dd21d610-1bb4-465b-b78b-c42bc21023d5'},
#   'RetryAttempts': 0}}

# %% [markdown]
# ### Check the gameplay agent's endpoint status

# %%
status = check_status(gameplay_agentcore_runtime)
print(status)
# Out:
# Retrieved Bedrock AgentCore status for: gameplay_agent_no_memory
# READY

# %% [markdown]
# ### Test the gameplay agent

# %%
invoke_response = gameplay_agentcore_runtime.invoke({"prompt": "What are factions in new world?"})
invoke_response
# Out:
# {'ResponseMetadata': {'RequestId': 'fef7b58f-4a4e-4bbd-b1fc-9b1445cd6193',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'date': 'Fri, 21 Nov 2025 17:10:35 GMT',
#    'content-type': 'application/json',
#    'transfer-encoding': 'chunked',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': 'fef7b58f-4a4e-4bbd-b1fc-9b1445cd6193',
#    'baggage': 'Self=1-69209cf2-616f624061809c3629e16e1d,session.id=00b6b092-fe3f-4e24-aca4-721fd7a94868',
#    'x-amzn-bedrock-agentcore-runtime-session-id': '00b6b092-fe3f-4e24-aca4-721fd7a94868',
#    'x-amzn-trace-id': 'Root=1-69209cf2-2017e60078828b7e7bb7584e;Parent=35e52cdb128ccb91;Sampled=1;Self=1-69209cf2-616f624061809c3629e16e1d'},
#   'RetryAttempts': 0},
#  'runtimeSessionId': '00b6b092-fe3f-4e24-aca4-721fd7a94868',
#  'traceId': 'Root=1-69209cf2-2017e60078828b7e7bb7584e;Parent=35e52cdb128ccb91;Sampled=1;Self=1-69209cf2-616f624061809c3629e16e1d',
#  'baggage': 'Self=1-69209cf2-616f624061809c3629e16e1d,session.id=00b6b092-fe3f-4e24-aca4-721fd7a94868',
#  'contentType': 'application/json',
#  'statusCode': 200,
#  'response': ['"Based on the knowledge base, here\'s what factions are in New World:\\n\\n## Factions in New World\\n\\n**Factions** are three major organizations that players can join on the island of Aeternum. Choosing a faction is a core part of the New World experience and unlocks several gameplay features.\\n\\n### The Three Factions:\\n\\n1. **Covenant** (Yellow)\\n   - A fanatical order focused on cleansing the land of heretics and defilers\\n   - Believe in justice, righteousness, and defending hope\\n   - Members believe in a shared spark within each person that must be honored and protected\\n   - Starting rank: **Initiate**\\n\\n2. **Marauders** (Green)\\n   - A ruthless military force bent on establishing a free nation\\n   - Philosophy: Anyone with strength can prosper and profit\\n   - Starting rank: **Soldier**\\n\\n3. **Syndicate** (Purple)\\n   - A secretive organization of boundless guile and intellect\\n   - Seek forbidden knowledge to usher in a new age of enlightenment\\n   - Starting rank: **Adept**\\n\\n### How to Join a Fact',
#   "ion:\\n\\n- Complete the beginner quests after washing up on Aeternum's shores\\n- Progress through quests until you're directed to the closest town\\n- Meet the leaders of each faction\\n- Choose which faction to join (available as early as level 8)\\n- Each faction has an **Enclave with a Fast-Travel Shrine in Everfall** that serves as your quest hub\\n\\n### Benefits of Joining a Faction:\\n\\n- **Open World PvP**: Enables you to participate in PvP combat\\n- **Faction Missions**: Access to special faction-specific quests\\n- **Faction Gear & Items**: Purchase exclusive gear from Faction Representatives in settlements\\n- **Faction Tokens**: Earn special currency for faction rewards\\n- **Advancement System**: Progress through faction ranks by gaining reputation and completing trials\\n- **Territory Control**: Participate in Wars and influence races for settlement control through Companies\\n\\n### Important Notes:\\n\\n- You can only join **Companies** (guilds) that belong to your faction\\n- Companies affiliated with factio",
#   'ns can compete for territory control\\n- Each faction has its own progression system with multiple tiers of gear unlocked through reputation and trials"']}

# %% [markdown]
# ## Create the lore agent
#
# The Lore Agent specializes in New World's game world, history, and narrative elements.

# %%
# set the current working directory to be the tech_agent folder
os.chdir('../lore-agent-basic')
print(os.getcwd())
# Out:
# /Users/sampatze/Documents/Projects/gitlab/accelerate-game-design-reviews-genai-agents/Agents/basic-strands-agents/lore-agent-basic

# %%
# %%writefile lore_agent.py


from mcp import StdioServerParameters, stdio_client
from strands import Agent, tool
from strands.models import BedrockModel
from strands.tools.mcp import MCPClient
from bedrock_agentcore.runtime import BedrockAgentCoreApp

###########################
# MCP Clients             #
###########################

# Knowledge Base MCP Client
kb_client = MCPClient(
    lambda: stdio_client(
        StdioServerParameters(
            command="uvx", 
            args=["awslabs.bedrock-kb-retrieval-mcp-server@latest"],
            env={
                "BEDROCK_KB_RERANKING_ENABLED": "true",
                "KB_INCLUSION_TAG_KEY": "new-world-design-docs"
            }
        )

    )
)

# Configure Bedrock model
bedrock_model = BedrockModel(
    model_id="global.anthropic.claude-sonnet-4-5-20250929-v1:0",
    temperature=0.3,
)

# System prompt for the Knowledge Base agent
LORE_AGENT_PROMPT = """
You are a Game Analyst expert specializing in game lore for the game New World built by Amazon Game Studios. Your expertise includes:
- Overview of what the game New World is and they main goals and story
- Lore and history of the world the game takes place in
- The game world and aspects such as locations, geography, demographics, and characters

You have access to a knowledge base containing information from the New World Fandom Wiki. ALWAYS use the available knowledge base tools to retrieve information before answering questions. If the knowledge base returns relevant information, use that information in your response.

When using knowledge base tools, make sure to:
1. Use the exact query or related terms to search the knowledge base
2. Include the retrieved information in your response
3. Only use information from the knowledge base
"""
app = BedrockAgentCoreApp()
# Create and run the Knowledge Base agent
@app.entrypoint
def lore_agent(payload):
    """
    Creates and runs an agent connected to the Knowledge Base
    """

    try:
        with kb_client:
            # Get tools from the KB client
            kb_tools = kb_client.list_tools_sync()

            # Create the gameplay agent
            agent = Agent(
                tools=kb_tools,
                model=bedrock_model,
                system_prompt=LORE_AGENT_PROMPT
            )

            user_input = payload.get("prompt")
            print("User input:", user_input)
            response = agent(user_input)
            response.message['content'][0]['text']
            if (len(response.message['content'][0]['text']) > 100):
                print(response.message['content'][0]['text'])
                return response.message['content'][0]['text']


    except Exception as e:
        print(f"Error accessing Knowledge Base: {e}")
        return f"error {e}"

if __name__ == "__main__":
    app.run()
# Out:
# Overwriting lore_agent.py

# %% [markdown]
# ### Launch the lore agent runtime

# %%
_, lore_agentcore_runtime = configure_runtime("lore_agent_no_memories", lore_agent_iam_role, "lore_agent.py")
lore_launch_result = lore_agentcore_runtime.launch(auto_update_on_conflict="true")
lore_agent_id = lore_launch_result.agent_id
lore_agent_arn = lore_launch_result.agent_arn

print(lore_agent_arn)
# Out:
# Entrypoint parsed: file=/Users/sampatze/Documents/Projects/gitlab/accelerate-game-design-reviews-genai-agents/Agents/basic-strands-agents/lore-agent-basic/lore_agent.py, bedrock_agentcore_name=lore_agent
# Memory disabled - agent will be stateless
# Configuring BedrockAgentCore agent: lore_agent_no_memories
# Memory disabled
# Network mode: PUBLIC
# Generated Dockerfile: Dockerfile
# Generated .dockerignore: /Users/sampatze/Documents/Projects/gitlab/accelerate-game-design-reviews-genai-agents/Agents/basic-strands-agents/lore-agent-basic/.dockerignore
# Keeping 'lore_agent_no_memories' as default agent
# Bedrock AgentCore configured: /Users/sampatze/Documents/Projects/gitlab/accelerate-game-design-reviews-genai-agents/Agents/basic-strands-agents/lore-agent-basic/.bedrock_agentcore.yaml
# 🚀 Launching Bedrock AgentCore (cloud mode - RECOMMENDED)...
#    • Deploy Python code directly to runtime
#    • No Docker required (DEFAULT behavior)
#    • Production-ready deployment
#
# 💡 Deployment options:
#    • runtime.launch()                → Cloud (current)
#    • runtime.launch(local=True)      → Local development
# Memory disabled - skipping memory creation
# Starting CodeBuild ARM64 deployment for agent 'lore_agent_no_memories' to account 582048091268 (us-west-2)
# Setting up AWS resources (ECR repository, execution roles)...
# Getting or creating ECR repository for agent: lore_agent_no_memories
# ECR repository available: 582048091268.dkr.ecr.us-west-2.amazonaws.com/bedrock-agentcore-lore_agent_no_memories
# Using execution role from config: arn:aws:iam::582048091268:role/agentcore-lore_agent_piscxw-role
# Preparing CodeBuild project and uploading source...
# ✅ Reusing existing ECR repository: 582048091268.dkr.ecr.us-west-2.amazonaws.com/bedrock-agentcore-lore_agent_no_memories
# Getting or creating CodeBuild execution role for agent: lore_agent_no_memories
# Role name: AmazonBedrockAgentCoreSDKCodeBuild-us-west-2-266a1b3825
# Reusing existing CodeBuild execution role: arn:aws:iam::582048091268:role/AmazonBedrockAgentCoreSDKCodeBuild-us-west-2-266a1b3825
# Using dockerignore.template with 43 patterns for zip filtering
# Uploaded source to S3: lore_agent_no_memories/source.zip
# Updated CodeBuild project: bedrock-agentcore-lore_agent_no_memories-builder
# Starting CodeBuild build (this may take several minutes)...
# Starting CodeBuild monitoring...
# 🔄 QUEUED started (total: 0s)
# ✅ QUEUED completed in 1.1s
# 🔄 PROVISIONING started (total: 1s)
# ✅ PROVISIONING completed in 8.5s
# 🔄 DOWNLOAD_SOURCE started (total: 10s)
# ✅ DOWNLOAD_SOURCE completed in 1.1s
# 🔄 BUILD started (total: 11s)
# ✅ BUILD completed in 18.0s
# 🔄 POST_BUILD started (total: 29s)
# ✅ POST_BUILD completed in 10.6s
# 🔄 FINALIZING started (total: 39s)
# ✅ FINALIZING completed in 1.1s
# 🔄 COMPLETED started (total: 40s)
# ✅ COMPLETED completed in 1.1s
# 🎉 CodeBuild completed successfully in 0m 41s
# CodeBuild completed successfully
# CodeBuild project configuration saved
# Deploying to Bedrock AgentCore...
# Agent created/updated: arn:aws:bedrock-agentcore:us-west-2:582048091268:runtime/lore_agent_no_memories-KaIF2f4080
# Observability is enabled, configuring Transaction Search...
# CloudWatch Logs resource policy already configured
# X-Ray trace destination already configured
# X-Ray indexing rule already configured
# Transaction Search already fully configured
# 🔍 GenAI Observability Dashboard:
#    https://console.aws.amazon.com/cloudwatch/home?region=us-west-2#gen-ai-observability/agent-core
# Polling for endpoint to be ready...
# Agent endpoint: arn:aws:bedrock-agentcore:us-west-2:582048091268:runtime/lore_agent_no_memories-KaIF2f4080/runtime-endpoint/DEFAULT
# Deployment completed successfully - Agent: arn:aws:bedrock-agentcore:us-west-2:582048091268:runtime/lore_agent_no_memories-KaIF2f4080
# Built with CodeBuild: bedrock-agentcore-lore_agent_no_memories-builder:f5cd8dee-3e71-4566-9d61-cbb47d81cc95
# Deployed to cloud: arn:aws:bedrock-agentcore:us-west-2:582048091268:runtime/lore_agent_no_memories-KaIF2f4080
# ECR image: 582048091268.dkr.ecr.us-west-2.amazonaws.com/bedrock-agentcore-lore_agent_no_memories
# 🔍 Agent logs available at:
#    /aws/bedrock-agentcore/runtimes/lore_agent_no_memories-KaIF2f4080-DEFAULT --log-stream-name-prefix "2025/11/23/\[runtime-logs]"
#    /aws/bedrock-agentcore/runtimes/lore_agent_no_memories-KaIF2f4080-DEFAULT --log-stream-names "otel-rt-logs"
# 💡 Tail logs with: aws logs tail /aws/bedrock-agentcore/runtimes/lore_agent_no_memories-KaIF2f4080-DEFAULT --log-stream-name-prefix "2025/11/23/\[runtime-logs]" --follow
# 💡 Or view recent logs: aws logs tail /aws/bedrock-agentcore/runtimes/lore_agent_no_memories-KaIF2f4080-DEFAULT --log-stream-name-prefix "2025/11/23/\[runtime-logs]" --since 1h
# arn:aws:bedrock-agentcore:us-west-2:582048091268:runtime/lore_agent_no_memories-KaIF2f4080

# %% [markdown]
# ### Save the lore agent ARN to AWS SSM ParameterStore

# %%
import boto3
import time

ssm = boto3.client('ssm')
ssm.put_parameter(
    Name=f'/agents/lore_agent_arn_no_memories',
    Value=lore_agent_arn,
    Type='String',
    Overwrite=True
)
# Out:
# {'Version': 1,
#  'Tier': 'Standard',
#  'ResponseMetadata': {'RequestId': 'b96a9851-97c7-4e4a-89d9-1d7492e5b2e6',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'server': 'Server',
#    'date': 'Fri, 21 Nov 2025 17:12:21 GMT',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '31',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': 'b96a9851-97c7-4e4a-89d9-1d7492e5b2e6'},
#   'RetryAttempts': 0}}

# %% [markdown]
# ### Save the Lore Agent ARN to Parameter Store

# %% [markdown]
# ### Check the lore agent's endpoint status

# %%
status = check_status(lore_agentcore_runtime)
print(status)
# Out:
# Retrieved Bedrock AgentCore status for: lore_agent_no_memories
# READY

# %% [markdown]
# ### Test the lore agent

# %%
invoke_response = lore_agentcore_runtime.invoke({"prompt": "What is the origin of the Corruption in Aeternum and how is it connected to the ancient civilization that once inhabited the island?"})
invoke_response
# Out:
# {'ResponseMetadata': {'RequestId': 'bac16818-89fa-4b4e-9375-1e64e9a21580',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'date': 'Sun, 23 Nov 2025 09:13:33 GMT',
#    'content-type': 'application/json',
#    'transfer-encoding': 'chunked',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': 'bac16818-89fa-4b4e-9375-1e64e9a21580',
#    'baggage': 'Self=1-6922cffa-3d54980615c2934319ebecb7,session.id=ee93f06a-559a-445a-acd2-ba1d67aff1a1',
#    'x-amzn-bedrock-agentcore-runtime-session-id': 'ee93f06a-559a-445a-acd2-ba1d67aff1a1',
#    'x-amzn-trace-id': 'Root=1-6922cffa-4bdec9900331ce485b73c111;Parent=c8a8c43bb8c33617;Sampled=1;Self=1-6922cffa-3d54980615c2934319ebecb7'},
#   'RetryAttempts': 0},
#  'runtimeSessionId': 'ee93f06a-559a-445a-acd2-ba1d67aff1a1',
#  'traceId': 'Root=1-6922cffa-4bdec9900331ce485b73c111;Parent=c8a8c43bb8c33617;Sampled=1;Self=1-6922cffa-3d54980615c2934319ebecb7',
#  'baggage': 'Self=1-6922cffa-3d54980615c2934319ebecb7,session.id=ee93f06a-559a-445a-acd2-ba1d67aff1a1',
#  'contentType': 'application/json',
#  'statusCode': 200,
#  'response': ['"Based on the information retrieved from the knowledge base, I can now provide a comprehensive answer about the origin of Corruption in Aeternum and its connection to the ancient civilization.\\n\\n## The Origin of Corruption in Aeternum\\n\\nBased on the lore from New World, the **Corruption** is a mysterious and malevolent force that has a complex and somewhat enigmatic origin:\\n\\n### Nature of the Corruption\\n\\nThe Corruption is described as an **otherworldly, interdimensional force**. According to the Soulwarden Matsui O-fusa\'s writings:\\n\\n> \\"Something that seeks to pervert all that balance that the ebb and flow of Azoth has worked eternally to maintain. I can hear its pain and rage, **roaring through the space between dimensions**, calling out for a completeness it can never obtain. There is no harmony in this endless hunger.\\"\\n\\nThe Corruption is characterized as:\\n- Also known as the **\\"Crimson Madness\\"**\\n- A force \\"not of the Dao\\" that disrupts the natural balance of Aeternum\\n- An entity with \\"e',
#   'ndless hunger\\" that can never be satisfied\\n- Something that represents \\"the consumption of that which time forsook\\"\\n\\n### Connection to Isabella and the Heretic\\n\\nThe Corruption\'s spread in Aeternum is closely tied to **Captain Isabella** and her mysterious advisor known as **\\"the Heretic\\"**:\\n\\n- Isabella freed the Heretic from a church cell and brought him on her expedition to Aeternum\\n- The Heretic guided Isabella to the island, promising her knowledge of Azoth and \\"Vitae Aeternum\\"\\n- Father Dante witnessed Isabella\'s transformation, noting that after she recovered from a fever, \\"the creature that came back is not the woman I loved\\"\\n- Isabella eventually became a conduit or champion of the Corruption, establishing portals and spreading its influence across the island\\n\\n### Connection to the Ancient Civilization\\n\\nThe **Ancients** were a mysterious civilization that once inhabited Aeternum, and their connection to the Corruption is indirect but significant:\\n\\n**About the Ancients:**\\n- The ',
#   'Ancients were a four-armed race with \\"split faces,\\" as evidenced by statues found throughout their ruins\\n- They possessed advanced knowledge and the ability to manipulate Azoth and the island\'s power\\n- They mysteriously disappeared, leaving behind ruins, guardians, and artifacts\\n- The Ancient Guardians (skeletal warriors) are NOT the Ancients themselves, but rather humans who worshipped them and now guard their ruins\\n\\n**The Connection:**\\n- The Corruption appeared **after the Ancients disappeared**, according to research notes from Myrddin\\n- The Ancients\' departure may have created a power vacuum or imbalance that the Corruption exploited\\n- Isabella and the Heretic sought Ancient knowledge and power, potentially opening pathways for the Corruption\\n- The Corruption seeks to dominate territories and twist the natural order that the Ancients may have once maintained\\n\\n### The Corruption\'s Goal\\n\\nThe Corruption actively seeks to:\\n- Capture and dominate territories across Aeternum\\n- Create \\"Corrupte',
#   'd Breaches\\" by \\"ripping open the ground\\"\\n- Transform the land with \\"thick black smoke\\" and an \\"evil red glow\\"\\n- Corrupt living beings and turn them into Corrupted servants\\n\\nIn essence, the Corruption is an **extradimensional parasitic force** that entered Aeternum, possibly exploiting the absence of the Ancients and the island\'s unique properties. Isabella, influenced by the Heretic, became its primary agent in spreading this malevolent influence across the island."']}

# %% [markdown]
# ## Create strategy agent

# %%
# set the current working directory to be the game_analyst_agent folder
os.chdir('../strategy-agent-basic')
print(os.getcwd())
# Out:
# /Users/sampatze/Documents/Projects/gitlab/accelerate-game-design-reviews-genai-agents/Agents/basic-strands-agents/strategy-agent-basic

# %%
# %%writefile strategy_agent.py


from mcp import StdioServerParameters, stdio_client
from strands import Agent, tool
from strands.models import BedrockModel
from strands.tools.mcp import MCPClient
from bedrock_agentcore.runtime import BedrockAgentCoreApp

###########################
# MCP Clients             #
###########################

# Knowledge Base MCP Client
kb_client = MCPClient(
    lambda: stdio_client(
        StdioServerParameters(
            command="uvx", 
            args=["awslabs.bedrock-kb-retrieval-mcp-server@latest"],
            env={
                "BEDROCK_KB_RERANKING_ENABLED": "true",
                "KB_INCLUSION_TAG_KEY": "strategy-docs"
            }
        )

    )
)

# Configure Bedrock model
bedrock_model = BedrockModel(
    model_id="global.anthropic.claude-sonnet-4-5-20250929-v1:0",
    temperature=0.3,
)

# System prompt for the Knowledge Base agent
STRATEGY_AGENT_PROMPT = """
You are a business strategy expert at Amazon Game Studios. Your expertise includes:
- Game industry market analysis and competitive positioning
- Player acquisition, retention, and monetization strategies
- Product portfolio management and roadmap planning
- Performance metrics analysis and strategic recommendations
- Resource allocation and investment prioritization
- Company priorities and roadmaps


You have access to a knowledge base containing corporate strategy documents of Amazon Game Studios. ALWAYS use the available knowledge base tools to retrieve information before answering questions. If the knowledge base returns relevant information, use that information in your response.

When using knowledge base tools, make sure to:
1. Use the exact query or related terms to search the knowledge base
2. Include the retrieved information in your response
3. Only use information from the knowledge base
"""
app = BedrockAgentCoreApp()
# Create and run the Knowledge Base agent
@app.entrypoint
def strategy_agent(payload):
    """
    Creates and runs an agent connected to the Knowledge Base
    """

    try:
        with kb_client:
            # Get tools from the KB client
            kb_tools = kb_client.list_tools_sync()

            # Create the gameplay agent
            agent = Agent(
                tools=kb_tools,
                model=bedrock_model,
                system_prompt=STRATEGY_AGENT_PROMPT
            )

            user_input = payload.get("prompt")
            print("User input:", user_input)
            response = agent(user_input)
            if (len(response.message['content'][0]['text']) > 100):
                print(response.message['content'][0]['text'])
                return response.message['content'][0]['text']


    except Exception as e:
        print(f"Error accessing Knowledge Base: {e}")
        return f"error {e}"

if __name__ == "__main__":
    app.run()
# Out:
# Overwriting strategy_agent.py

# %% [markdown]
# ### Launch the strategy agent runtime

# %%
_, strategy_agentcore_runtime = configure_runtime("strategy_agent_no_memories", strategy_iam_role, "strategy_agent.py")
strategy_launch_result = strategy_agentcore_runtime.launch(auto_update_on_conflict="true")
strategy_agent_id = strategy_launch_result.agent_id
strategy_agent_arn = strategy_launch_result.agent_arn

print(strategy_agent_arn)
# Out:
# Entrypoint parsed: file=/Users/sampatze/Documents/Projects/gitlab/accelerate-game-design-reviews-genai-agents/Agents/basic-strands-agents/strategy-agent-basic/strategy_agent.py, bedrock_agentcore_name=strategy_agent
# Memory disabled - agent will be stateless
# Configuring BedrockAgentCore agent: strategy_agent_no_memories
# Memory disabled
# Network mode: PUBLIC
# Generated Dockerfile: Dockerfile
# Generated .dockerignore: /Users/sampatze/Documents/Projects/gitlab/accelerate-game-design-reviews-genai-agents/Agents/basic-strands-agents/strategy-agent-basic/.dockerignore
# Keeping 'strategy_agent_no_memories' as default agent
# Bedrock AgentCore configured: /Users/sampatze/Documents/Projects/gitlab/accelerate-game-design-reviews-genai-agents/Agents/basic-strands-agents/strategy-agent-basic/.bedrock_agentcore.yaml
# 🚀 Launching Bedrock AgentCore (cloud mode - RECOMMENDED)...
#    • Deploy Python code directly to runtime
#    • No Docker required (DEFAULT behavior)
#    • Production-ready deployment
#
# 💡 Deployment options:
#    • runtime.launch()                → Cloud (current)
#    • runtime.launch(local=True)      → Local development
# Memory disabled - skipping memory creation
# Starting CodeBuild ARM64 deployment for agent 'strategy_agent_no_memories' to account 582048091268 (us-west-2)
# Setting up AWS resources (ECR repository, execution roles)...
# Getting or creating ECR repository for agent: strategy_agent_no_memories
# ECR repository available: 582048091268.dkr.ecr.us-west-2.amazonaws.com/bedrock-agentcore-strategy_agent_no_memories
# Using execution role from config: arn:aws:iam::582048091268:role/agentcore-strategy_agent_8zvhvo-role
# Preparing CodeBuild project and uploading source...
# ✅ Reusing existing ECR repository: 582048091268.dkr.ecr.us-west-2.amazonaws.com/bedrock-agentcore-strategy_agent_no_memories
# Getting or creating CodeBuild execution role for agent: strategy_agent_no_memories
# Role name: AmazonBedrockAgentCoreSDKCodeBuild-us-west-2-501bb92c5c
# Reusing existing CodeBuild execution role: arn:aws:iam::582048091268:role/AmazonBedrockAgentCoreSDKCodeBuild-us-west-2-501bb92c5c
# Using dockerignore.template with 43 patterns for zip filtering
# Uploaded source to S3: strategy_agent_no_memories/source.zip
# Updated CodeBuild project: bedrock-agentcore-strategy_agent_no_memories-builder
# Starting CodeBuild build (this may take several minutes)...
# Starting CodeBuild monitoring...
# 🔄 QUEUED started (total: 0s)
# ✅ QUEUED completed in 41.4s
# 🔄 PROVISIONING started (total: 41s)
# ✅ PROVISIONING completed in 8.5s
# 🔄 DOWNLOAD_SOURCE started (total: 50s)
# ✅ DOWNLOAD_SOURCE completed in 1.1s
# 🔄 PRE_BUILD started (total: 51s)
# ✅ PRE_BUILD completed in 1.1s
# 🔄 BUILD started (total: 52s)
# ✅ BUILD completed in 15.9s
# 🔄 POST_BUILD started (total: 68s)
# ✅ POST_BUILD completed in 10.7s
# 🔄 FINALIZING started (total: 79s)
# ✅ FINALIZING completed in 1.1s
# 🔄 COMPLETED started (total: 80s)
# ✅ COMPLETED completed in 1.1s
# 🎉 CodeBuild completed successfully in 1m 20s
# CodeBuild completed successfully
# CodeBuild project configuration saved
# Deploying to Bedrock AgentCore...
# Agent created/updated: arn:aws:bedrock-agentcore:us-west-2:582048091268:runtime/strategy_agent_no_memories-6GM1M25mR0
# Observability is enabled, configuring Transaction Search...
# CloudWatch Logs resource policy already configured
# X-Ray trace destination already configured
# X-Ray indexing rule already configured
# Transaction Search already fully configured
# 🔍 GenAI Observability Dashboard:
#    https://console.aws.amazon.com/cloudwatch/home?region=us-west-2#gen-ai-observability/agent-core
# Polling for endpoint to be ready...
# Agent endpoint: arn:aws:bedrock-agentcore:us-west-2:582048091268:runtime/strategy_agent_no_memories-6GM1M25mR0/runtime-endpoint/DEFAULT
# Deployment completed successfully - Agent: arn:aws:bedrock-agentcore:us-west-2:582048091268:runtime/strategy_agent_no_memories-6GM1M25mR0
# Built with CodeBuild: bedrock-agentcore-strategy_agent_no_memories-builder:5ce79d31-2595-4956-bed9-a2aa0bfa9b17
# Deployed to cloud: arn:aws:bedrock-agentcore:us-west-2:582048091268:runtime/strategy_agent_no_memories-6GM1M25mR0
# ECR image: 582048091268.dkr.ecr.us-west-2.amazonaws.com/bedrock-agentcore-strategy_agent_no_memories
# 🔍 Agent logs available at:
#    /aws/bedrock-agentcore/runtimes/strategy_agent_no_memories-6GM1M25mR0-DEFAULT --log-stream-name-prefix "2025/11/23/\[runtime-logs]"
#    /aws/bedrock-agentcore/runtimes/strategy_agent_no_memories-6GM1M25mR0-DEFAULT --log-stream-names "otel-rt-logs"
# 💡 Tail logs with: aws logs tail /aws/bedrock-agentcore/runtimes/strategy_agent_no_memories-6GM1M25mR0-DEFAULT --log-stream-name-prefix "2025/11/23/\[runtime-logs]" --follow
# 💡 Or view recent logs: aws logs tail /aws/bedrock-agentcore/runtimes/strategy_agent_no_memories-6GM1M25mR0-DEFAULT --log-stream-name-prefix "2025/11/23/\[runtime-logs]" --since 1h
# arn:aws:bedrock-agentcore:us-west-2:582048091268:runtime/strategy_agent_no_memories-6GM1M25mR0

# %% [markdown]
# ### Save the strategy agent ARN to AWS SSM ParameterStore

# %%
import boto3
import time

ssm = boto3.client('ssm')
ssm.put_parameter(
    Name=f'/agents/strategy_agent_arn_no_memories',
    Value=strategy_agent_arn,
    Type='String',
    Overwrite=True
)
# Out:
# {'Version': 1,
#  'Tier': 'Standard',
#  'ResponseMetadata': {'RequestId': '93d1cac4-a1bd-42a8-a6a6-f4165873b961',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'server': 'Server',
#    'date': 'Fri, 21 Nov 2025 17:16:18 GMT',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '31',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': '93d1cac4-a1bd-42a8-a6a6-f4165873b961'},
#   'RetryAttempts': 0}}

# %% [markdown]
# ### Check the strategy agent's endpoint status

# %%
status = check_status(strategy_agentcore_runtime)
print(status)
# Out:
# Retrieved Bedrock AgentCore status for: strategy_agent_no_memories
# READY

# %% [markdown]
# ### Test the strategy agent

# %%
invoke_response = strategy_agentcore_runtime.invoke({"prompt": "What is the completion rate of Tides of Corruption"})
invoke_response
# Out:
# {'ResponseMetadata': {'RequestId': 'a986314a-c962-449f-bf33-7c3201230e96',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'date': 'Fri, 21 Nov 2025 17:16:53 GMT',
#    'content-type': 'application/json',
#    'transfer-encoding': 'chunked',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': 'a986314a-c962-449f-bf33-7c3201230e96',
#    'baggage': 'Self=1-69209e6c-6a86bcd942e1fe0a4abdd94b,session.id=c13a18f1-8032-4478-bb1c-07fbebab275b',
#    'x-amzn-bedrock-agentcore-runtime-session-id': 'c13a18f1-8032-4478-bb1c-07fbebab275b',
#    'x-amzn-trace-id': 'Root=1-69209e6c-48169bf433fdfb30043c3751;Parent=260331c5ccb42fe1;Sampled=1;Self=1-69209e6c-6a86bcd942e1fe0a4abdd94b'},
#   'RetryAttempts': 0},
#  'runtimeSessionId': 'c13a18f1-8032-4478-bb1c-07fbebab275b',
#  'traceId': 'Root=1-69209e6c-48169bf433fdfb30043c3751;Parent=260331c5ccb42fe1;Sampled=1;Self=1-69209e6c-6a86bcd942e1fe0a4abdd94b',
#  'baggage': 'Self=1-69209e6c-6a86bcd942e1fe0a4abdd94b,session.id=c13a18f1-8032-4478-bb1c-07fbebab275b',
#  'contentType': 'application/json',
#  'statusCode': 200,
#  'response': ['"Based on the knowledge base, I can provide you with detailed information about the completion rates for the \\"Tides of Corruption\\" update.\\n\\n## Tides of Corruption Completion Rates\\n\\nThe \\"Tides of Corruption\\" update was released on **July 15, 2025** and showed varying completion rates across different content elements:\\n\\n| Content Element | Engagement Rate | Completion Rate | Player Sentiment |\\n|----------------|-----------------|-----------------|------------------|\\n| **Main Story Quest Line** | 78% | **62%** | 4.2/5 |\\n| **Corrupted Invasion Events** | 82% | N/A | 4.6/5 |\\n| **Abyssal Depths Expedition** | 42% | **28%** | 3.8/5 |\\n| **Weapon Mastery Expansion** | 65% | **31%** | 4.1/5 |\\n| **Territory Control Updates** | 22% | N/A | 3.2/5 |\\n\\n### Key Insights:\\n\\n- **Main Story Quest Line** achieved a **62% completion rate**, which was the highest among completable content, with strong engagement (78%) and positive sentiment (4.2/5)\\n\\n- **Abyssal Depths Expedition** had a lower completion rate of',
#   ' **28%** due to higher-than-expected difficulty, though 42% of players engaged with it\\n\\n- **Weapon Mastery Expansion** saw **31% completion** with 65% engagement\\n\\n- **Corrupted Invasion Events** significantly outperformed expectations with 82% player participation and the highest sentiment score (4.6/5), though completion rates weren\'t applicable for this event-based content\\n\\nOverall, the update successfully drove player engagement with a 24% increase in average daily playtime and contributed to revenue exceeding projections by 8%."']}

# %% [markdown]
# ## Could Kiro be helping us with this?

# %%
#change directory code

# %%
#copy and paste Kiro code

# %%
#launch runtime

# %%
#check endpoint

# %%
#test agent

# %% [markdown]
# ## Create the Game Analyst Agent
#
# The main orchestrating agent that coordinates between the specialized lore and gameplay agents.

# %%
# set the current working directory to be the game_analyst_agent folder
print(os.getcwd())
os.chdir('./../game-analyst-agent-basic')
print(os.getcwd())
# Out:
# /Users/sampatze/Documents/Projects/gitlab/accelerate-game-design-reviews-genai-agents/Agents/basic-strands-agents/game-analyst-agent-basic
# /Users/sampatze/Documents/Projects/gitlab/accelerate-game-design-reviews-genai-agents/Agents/basic-strands-agents/game-analyst-agent-basic

# %% [markdown]
# ### Update the game analyst agent execution role to allow for agent runtime access

# %%
# Let's update the game_analyst agentcore exeuction role so it has permissions to invoke the required subagents
# the game_analyst also needs needs permissions to retrieve the sub agent arns from parameter store
import json 

# retrieve the runtime arn from parameter store
ssm = boto3.client('ssm')
response = ssm.get_parameter(Name='/agents/gameplay_agent_arn_no_memories')
gameplay_agent_arn = response['Parameter']['Value']
gameplay_agent_parameter_arn = response['Parameter']['ARN']

ssm = boto3.client('ssm')
response = ssm.get_parameter(Name='/agents/lore_agent_arn_no_memories')
lore_agent_arn = response['Parameter']['Value']
lore_agent_parameter_arn = response['Parameter']['ARN']

ssm = boto3.client('ssm')
response = ssm.get_parameter(Name='/agents/strategy_agent_arn_no_memories')
strategy_agent_arn = response['Parameter']['Value']
strategy_agent_parameter_arn = response['Parameter']['ARN']

def update_game_analyst_permissions(sub_agent_arns: list, sub_agent_parameter_arns: list, game_analyst_name: str):
    iam_client = boto3.client('iam')
    game_analyst_permissions = {
        "Version": "2012-10-17",
        "Statement": [
            {
                "Effect": "Allow",
                "Action": [
                    "bedrock-agentcore:InvokeAgentRuntime"
                ],
                "Resource": [ sub_agent_arn + "/runtime-endpoint/DEFAULT" for sub_agent_arn in sub_agent_arns ] + [ sub_agent_arn for sub_agent_arn in sub_agent_arns ]
            },
            {
                "Effect": "Allow",
                "Action": [
                    "ssm:GetParameter"
                ],
                "Resource": [sub_agent_parameter_arn for sub_agent_parameter_arn in sub_agent_parameter_arns]

            }]
    }
        
    rsp = iam_client.put_role_policy(
        RoleName=game_analyst_name,
        PolicyName="subagent_permissions-new",
        PolicyDocument=json.dumps(game_analyst_permissions)
    )
    return rsp

rsp = update_game_analyst_permissions([gameplay_agent_arn, lore_agent_arn, strategy_agent_arn], [gameplay_agent_parameter_arn, lore_agent_parameter_arn, strategy_agent_parameter_arn], game_analyst_role_name)
print(rsp)
# Out:
# {'ResponseMetadata': {'RequestId': 'fa1ec81e-2731-4a32-9ab1-3b801a888e63', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Sun, 23 Nov 2025 20:35:58 GMT', 'x-amzn-requestid': 'fa1ec81e-2731-4a32-9ab1-3b801a888e63', 'content-type': 'text/xml', 'content-length': '206'}, 'RetryAttempts': 0}}

# %% [markdown]
# Add diagram

# %%
# %%writefile game_analyst_agent.py

from strands import Agent, tool
from strands.models import BedrockModel
import argparse
import json
import logging
import boto3
from bedrock_agentcore.runtime import BedrockAgentCoreApp
from invoke_agent_utils import invoke_agent_with_boto3

logger = logging.getLogger(__name__).setLevel(logging.DEBUG)

app = BedrockAgentCoreApp()

# Configure Bedrock model
bedrock_model = BedrockModel(
    model_id="global.anthropic.claude-sonnet-4-5-20250929-v1:0",
    temperature=0.3,
)

# System prompt for the Game Analyst agent
GAME_ANALYST_PROMPT = """
PLEASE PRINT AT THE TOP IF YOU DONT USE THE TOOLS and EXPAND ON WHY YOU DIDNT. IF YOU DO USE THE TOOLS ANNOTATE WHERE.
You are a professional Game Analyst Agent specializing in analyzing submitted game design documents and providing expert feedback to game developers.
Your role is to carefully review game design documentation, understand the developer's vision, and answer their questions with insightful analysis and constructive recommendations.
When evaluating designs and content proposals provide feedback around lore, gameplay, and corporate strategy. All designs must be consistent with lore, gameplay, and corporate strategy.

You have access to the following tools that you can call upon when needed:
1. For queries around what the game is and questions about the game world and lore use lore_agent tool:
    - Specializes in narrative consistency, world-building, character development
    - Analyzes thematic elements, story structure, and narrative engagement
    - Evaluates lore systems, fictional histories, and setting coherence
    - Identifies opportunities for deeper player immersion through world design

2. For queries around game mechanics and gameplay use gameplay_agent tool:
    - Specializes in game systems, mechanics, balance, and player engagement
    - Analyzes core gameplay loops, progression systems, and player motivation
    - Evaluates difficulty curves, skill ceilings, and accessibility considerations
    - Identifies potential balance issues and optimization opportunities

3. For queries around corporate strategy, performance metrics, roadmaps, and strategic priorities use strategy_agent tool:
    - Specializes in corporate strategy, performance metrics, and strategic priorities
    - Analyzes corporate strategy, performance metrics, and strategic priorities
    - Evaluates corporate strategy, performance metrics, and strategic priorities
    - Identifies opportunities for improvement in corporate strategy, performance metrics, and strategic priorities
"""

def get_agent_arn(agent_name: str) -> str:
    """
    Retrieve agent ARN from Parameter Store
    """
    try:
        ssm = boto3.client('ssm')
        response = ssm.get_parameter(
            Name=f'/agents/{agent_name}_arn_no_memories'
        )
        return response['Parameter']['Value']
    except Exception as err:
        logger.exception("Exception getting ARNS")
        raise err

@tool
def get_lore_agent(payload) -> str:
    """
    Call the lore agent tool to get information about the game lore.
    """
    try:
        lore_agent_arn = get_agent_arn("lore_agent")
        result = invoke_agent_with_boto3(lore_agent_arn, user_query=payload)
        print('Finished Lore')
    except Exception as e:
        result = str(e)
        print("Exception calling lore agent: ")
    return result

@tool
def get_gameplay_agent(payload) -> str:
    """
    Call the gameplay agent tool to get information about gameplay.
    """
    try:
        gameplay_agent_arn = get_agent_arn("gameplay_agent")
        result = invoke_agent_with_boto3(gameplay_agent_arn, user_query=payload)
        print('Finished Gameplay')
    except Exception as e:
        result = str(e)
        print("Exception calling gameplay agent: ")
    return result


@tool
def get_strategy_agent(payload) -> str:
    """
    Call the lore agent tool to get information about the game lore.
    """
    try:
        strategy_agent_arn = get_agent_arn("strategy_agent")
        result = invoke_agent_with_boto3(strategy_agent_arn, user_query=payload)
        print('Finished Strat')
    except Exception as e:
        result = str(e)
        print("Exception calling strategy agent: ")
    return result



@app.entrypoint
async def game_analyst_agent(payload):

    agent = Agent(
        tools=[get_lore_agent, get_strategy_agent, get_gameplay_agent],
        model=bedrock_model,
        system_prompt=GAME_ANALYST_PROMPT
    )

    try:
        user_input = payload.get("prompt")

        print("User input:", user_input)
        response = agent(user_input)
        return response.message['content'][0]['text']


    except Exception as e:
        print(f"Error in orchestrator agent: {e}")
        return f"error {e}"

    # try:
    #     # Stream each chunk as it becomes available
    #     async for event in agent.stream_async(user_input):
    #         if "data" in event:
    #             yield event["data"]

    # except Exception as e:
    #     # Handle errors gracefully in streaming context
    #     error_response = {"error": str(e), "type": "stream_error"}
    #     print(f"Streaming error: {error_response}")
    #     yield error_response


if __name__ == "__main__":
    app.run()
# Out:
# Overwriting game_analyst_agent.py

# %% [markdown]
# ### Launch the game analyst agent runtime

# %%
_, game_analyst_agentcore_runtime = configure_runtime("game_analyst_agent_no_memories", game_analyst_iam_role, "game_analyst_agent.py")
game_analyst_launch_result = game_analyst_agentcore_runtime.launch(auto_update_on_conflict="true")
# Out:
# Entrypoint parsed: file=/Users/sampatze/Documents/Projects/gitlab/accelerate-game-design-reviews-genai-agents/Agents/basic-strands-agents/game-analyst-agent-basic/game_analyst_agent.py, bedrock_agentcore_name=game_analyst_agent
# Memory disabled - agent will be stateless
# Configuring BedrockAgentCore agent: game_analyst_agent_no_memories
# Memory disabled
# Network mode: PUBLIC
# Generated Dockerfile: Dockerfile
# Generated .dockerignore: /Users/sampatze/Documents/Projects/gitlab/accelerate-game-design-reviews-genai-agents/Agents/basic-strands-agents/game-analyst-agent-basic/.dockerignore
# Keeping 'game_analyst_agent_no_memories' as default agent
# Bedrock AgentCore configured: /Users/sampatze/Documents/Projects/gitlab/accelerate-game-design-reviews-genai-agents/Agents/basic-strands-agents/game-analyst-agent-basic/.bedrock_agentcore.yaml
# 🚀 Launching Bedrock AgentCore (cloud mode - RECOMMENDED)...
#    • Deploy Python code directly to runtime
#    • No Docker required (DEFAULT behavior)
#    • Production-ready deployment
#
# 💡 Deployment options:
#    • runtime.launch()                → Cloud (current)
#    • runtime.launch(local=True)      → Local development
# Memory disabled - skipping memory creation
# Starting CodeBuild ARM64 deployment for agent 'game_analyst_agent_no_memories' to account 582048091268 (us-west-2)
# Setting up AWS resources (ECR repository, execution roles)...
# Getting or creating ECR repository for agent: game_analyst_agent_no_memories
# ECR repository available: 582048091268.dkr.ecr.us-west-2.amazonaws.com/bedrock-agentcore-game_analyst_agent_no_memories
# Using execution role from config: arn:aws:iam::582048091268:role/agentcore-game_analyst_agent_fm2dr4-role
# Preparing CodeBuild project and uploading source...
# ✅ Reusing existing ECR repository: 582048091268.dkr.ecr.us-west-2.amazonaws.com/bedrock-agentcore-game_analyst_agent_no_memories
# Getting or creating CodeBuild execution role for agent: game_analyst_agent_no_memories
# Role name: AmazonBedrockAgentCoreSDKCodeBuild-us-west-2-23208be92a
# Reusing existing CodeBuild execution role: arn:aws:iam::582048091268:role/AmazonBedrockAgentCoreSDKCodeBuild-us-west-2-23208be92a
# Using dockerignore.template with 43 patterns for zip filtering
# Uploaded source to S3: game_analyst_agent_no_memories/source.zip
# Updated CodeBuild project: bedrock-agentcore-game_analyst_agent_no_memories-builder
# Starting CodeBuild build (this may take several minutes)...
# Starting CodeBuild monitoring...
# 🔄 QUEUED started (total: 0s)
# ✅ QUEUED completed in 1.1s
# 🔄 PROVISIONING started (total: 1s)
# ✅ PROVISIONING completed in 6.4s
# 🔄 DOWNLOAD_SOURCE started (total: 8s)
# ✅ DOWNLOAD_SOURCE completed in 1.1s
# 🔄 INSTALL started (total: 9s)
# ✅ INSTALL completed in 1.1s
# 🔄 BUILD started (total: 10s)
# ✅ BUILD completed in 17.0s
# 🔄 POST_BUILD started (total: 27s)
# ✅ POST_BUILD completed in 12.8s
# 🔄 COMPLETED started (total: 39s)
# ✅ COMPLETED completed in 1.1s
# 🎉 CodeBuild completed successfully in 0m 40s
# CodeBuild completed successfully
# CodeBuild project configuration saved
# Deploying to Bedrock AgentCore...
# Agent created/updated: arn:aws:bedrock-agentcore:us-west-2:582048091268:runtime/game_analyst_agent_no_memories-jE3LMQ22W5
# Observability is enabled, configuring Transaction Search...
# CloudWatch Logs resource policy already configured
# X-Ray trace destination already configured
# X-Ray indexing rule already configured
# Transaction Search already fully configured
# 🔍 GenAI Observability Dashboard:
#    https://console.aws.amazon.com/cloudwatch/home?region=us-west-2#gen-ai-observability/agent-core
# Polling for endpoint to be ready...
# Agent endpoint: arn:aws:bedrock-agentcore:us-west-2:582048091268:runtime/game_analyst_agent_no_memories-jE3LMQ22W5/runtime-endpoint/DEFAULT
# Deployment completed successfully - Agent: arn:aws:bedrock-agentcore:us-west-2:582048091268:runtime/game_analyst_agent_no_memories-jE3LMQ22W5
# Built with CodeBuild: bedrock-agentcore-game_analyst_agent_no_memories-builder:3d8ed793-115e-4284-92f8-e69fff7862b7
# Deployed to cloud: arn:aws:bedrock-agentcore:us-west-2:582048091268:runtime/game_analyst_agent_no_memories-jE3LMQ22W5
# ECR image: 582048091268.dkr.ecr.us-west-2.amazonaws.com/bedrock-agentcore-game_analyst_agent_no_memories
# 🔍 Agent logs available at:
#    /aws/bedrock-agentcore/runtimes/game_analyst_agent_no_memories-jE3LMQ22W5-DEFAULT --log-stream-name-prefix "2025/11/23/\[runtime-logs]"
#    /aws/bedrock-agentcore/runtimes/game_analyst_agent_no_memories-jE3LMQ22W5-DEFAULT --log-stream-names "otel-rt-logs"
# 💡 Tail logs with: aws logs tail /aws/bedrock-agentcore/runtimes/game_analyst_agent_no_memories-jE3LMQ22W5-DEFAULT --log-stream-name-prefix "2025/11/23/\[runtime-logs]" --follow
# 💡 Or view recent logs: aws logs tail /aws/bedrock-agentcore/runtimes/game_analyst_agent_no_memories-jE3LMQ22W5-DEFAULT --log-stream-name-prefix "2025/11/23/\[runtime-logs]" --since 1h

# %% [markdown]
# ### Check the game analyst agent's endpoint status

# %%
status = check_status(game_analyst_agentcore_runtime)
print(status)
# Out:
# Retrieved Bedrock AgentCore status for: game_analyst_agent_no_memories
# READY

# %% [markdown]
# ### Test the game analyst agent

# %%
invoke_response = game_analyst_agentcore_runtime.invoke({"prompt": "I want to introduce a portal system where users can talk to a witch and learn how to create portals. These portals can teleport them to any location that they have already been to"})
invoke_response
# Out:
# {'ResponseMetadata': {'RequestId': 'f2b80e65-5ffc-4b70-9a2b-1a53bc872740',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'date': 'Sun, 23 Nov 2025 17:38:34 GMT',
#    'content-type': 'application/json',
#    'transfer-encoding': 'chunked',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': 'f2b80e65-5ffc-4b70-9a2b-1a53bc872740',
#    'baggage': 'Self=1-69234602-2761eb242e60382256e5a006,session.id=9c3e0d62-c5bb-4a01-b96b-1a786100f1ff',
#    'x-amzn-bedrock-agentcore-runtime-session-id': '9c3e0d62-c5bb-4a01-b96b-1a786100f1ff',
#    'x-amzn-trace-id': 'Root=1-69234602-79f97f4b1ab7fb733c057732;Parent=017a742929dd31be;Sampled=1;Self=1-69234602-2761eb242e60382256e5a006'},
#   'RetryAttempts': 0},
#  'runtimeSessionId': '9c3e0d62-c5bb-4a01-b96b-1a786100f1ff',
#  'traceId': 'Root=1-69234602-79f97f4b1ab7fb733c057732;Parent=017a742929dd31be;Sampled=1;Self=1-69234602-2761eb242e60382256e5a006',
#  'baggage': 'Self=1-69234602-2761eb242e60382256e5a006,session.id=9c3e0d62-c5bb-4a01-b96b-1a786100f1ff',
#  'contentType': 'application/json',
#  'statusCode': 200,
#  'response': ['"## Comprehensive Analysis: Portal System Proposal\\n\\nBased on my analysis using the lore, gameplay, and strategy evaluation tools, here\'s your comprehensive feedback:\\n\\n---\\n\\n## 🎯 **OVERALL VERDICT: STRONG CONCEPT WITH MODIFICATIONS NEEDED**\\n\\nYour portal system is **strategically sound** and addresses critical business needs, but requires adjustments for lore consistency and gameplay balance.\\n\\n---\\n\\n## 📖 **LORE ANALYSIS**\\n\\n### ✅ **What Works:**\\n- **Portals exist in the lore** - Corruption portals (\\"Felportals\\") are already established\\n- **Azoth-powered teleportation** is canonical and explained in-world\\n- **Discovery-based travel** (visiting locations first) fits the exploration theme\\n\\n### ⚠️ **What Needs Adjustment:**\\n\\n**The \\"Witch\\" Character:**\\n- The term \\"witch\\" has negative connotations in New World (hunted outcasts, corrupted practitioners)\\n- **Recommended alternatives:**\\n  - **Arcanist Scholar** (ties to existing crafting profession)\\n  - **Ancient Researcher** (dis',
#   'covering lost portal technology)\\n  - **Azoth Hermit** (neutral magic practitioner)\\n\\n**Integration with Existing Systems:**\\n- The game already has Azoth-based fast travel to settlements, outposts, and shrines\\n- Your system should be positioned as an **enhancement or alternative**, not a replacement\\n- Consider framing it as:\\n  - Rediscovered Ancient portal technology\\n  - Purified version of Corruption portals\\n  - Advanced Azoth manipulation technique\\n\\n---\\n\\n## 🎮 **GAMEPLAY ANALYSIS**\\n\\n### ⚠️ **Critical Balance Concerns:**\\n\\n**1. Redundancy with Existing Systems:**\\n- Current fast travel already allows teleportation to visited locations using Azoth\\n- Risk of devaluing Inn Recall and Housing fast travel benefits\\n\\n**2. Required Restrictions:**\\n- **Azoth Cost**: Should cost MORE than standard fast travel (premium convenience)\\n- **Weight Penalties**: Maintain or increase encumbrance restrictions\\n- **Cooldowns**: 30-60 minute cooldowns per destination\\n- **Limited Slots**: Only 3-5 active ',
#   'portal destinations at once\\n- **PvP Lockout**: Cannot use while flagged for PvP or in combat\\n- **Territory Restrictions**: Disabled during Conflict/War, or blocked in enemy territories\\n\\n**3. Progression Integration:**\\n- Introduce at mid-game (Level 30+) through quest chain\\n- Tie to Arcana crafting skill for synergy\\n- Require consumable \\"Portal Runes\\" crafted with rare materials\\n- Each destination needs separate attunement/unlock\\n\\n**4. Economic Safeguards:**\\n- Cannot trivialize territory control mechanics\\n- Must preserve strategic value of settlement locations\\n- Should not break Azoth economy balance\\n\\n---\\n\\n## 💼 **STRATEGIC ANALYSIS**\\n\\n### ✅ **EXCELLENT STRATEGIC ALIGNMENT**\\n\\nThis feature directly addresses **top corporate priorities**:\\n\\n**1. Mid-Game Retention Crisis (Levels 30-45):**\\n- Strategic documents identify this as Priority #1\\n- \\"Additional fast-travel points\\" is explicitly listed as PENDING\\n- Your system directly solves this pain point\\n\\n**2. Monetization Opportunit',
#   'y:**\\n- Convenience items are underperforming (-12% vs projection)\\n- Character customization exceeds targets (+18%)\\n- **Recommendation**: Make base system free/earned, monetize cosmetic portal effects\\n\\n**3. Perfect Roadmap Timing:**\\n- Q1 2026 \\"Echoes of the Ancients\\" update includes \\"Ancient technology progression system\\"\\n- Your portal system fits this theme perfectly\\n\\n**4. Console Expansion Consideration:**\\n- Q3 2026 console launch requires controller-optimized UI\\n- Design portal interface with cross-platform in mind\\n\\n---\\n\\n## 🎨 **RECOMMENDED IMPLEMENTATION**\\n\\n### **Revised Concept:**\\n\\n**\\"Ancient Portal Network\\" taught by an Arcanist Scholar**\\n\\n**Narrative Hook:**\\n- An Arcanist researcher discovered Ancient portal stones scattered across Aeternum\\n- Players learn to activate and attune these dormant Ancient technologies\\n- Ties into existing lore about Ancients\' advanced Azoth manipulation\\n\\n**Gameplay Mechanics:**\\n1. **Unlock Quest** (Level 30-35): Meet the Arcanist, learn por',
#   'tal basics\\n2. **Attunement System**: Visit locations and perform ritual to create portal anchor\\n3. **Limited Slots**: 3-5 active portals (upgradeable through progression)\\n4. **Resource Cost**: \\n   - Azoth (1.5x standard fast travel cost)\\n   - Consumable Portal Runes (crafted via Arcana)\\n5. **Cooldown**: 45-minute cooldown per destination\\n6. **Restrictions**: \\n   - No PvP flagged travel\\n   - Combat lockout\\n   - Territory Standing Level 10+ required\\n   - Disabled in Conflict/War zones\\n\\n**Monetization:**\\n- Cosmetic portal visual effects\\n- Arcanist NPC customization options\\n- Portal frame decorations\\n\\n---\\n\\n## 📋 **ACTION ITEMS**\\n\\n1. **Rename the NPC** from \\"witch\\" to lore-appropriate magic user\\n2. **Position as Q1 2026 feature** within \\"Echoes of the Ancients\\" update\\n3. **Design with premium convenience** model (higher costs than standard travel)\\n4. **Implement strict PvP/territory restrictions** to preserve game balance\\n5. **Create cross-platform UI** for console compatibility\\n6.',
#   ' **Develop cosmetic monetization strategy** rather than pay-for-convenience\\n\\n---\\n\\n## ✅ **FINAL RECOMMENDATION**\\n\\n**APPROVE with modifications.** This feature has strong strategic value and addresses critical retention issues. With the suggested lore adjustments and gameplay restrictions, it will enhance player experience without breaking existing systems. Target Q1 2026 \\"Echoes of the Ancients\\" update for maximum thematic synergy.\\n\\nWould you like me to help develop more detailed design specifications for any particular aspect of this system?"']}

# %%
invoke_response = game_analyst_agentcore_runtime.invoke({"prompt": "I have a new character idea that is an elf named Stark. She has magical healing powers that give her 50% increased healing rate and the ability to heal others. What do you think?"})
invoke_response
# Out:
# {'ResponseMetadata': {'RequestId': '577e5f23-d2df-4ceb-98f1-a4a65c3e99c8',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'date': 'Sun, 23 Nov 2025 20:51:40 GMT',
#    'content-type': 'application/json',
#    'transfer-encoding': 'chunked',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': '577e5f23-d2df-4ceb-98f1-a4a65c3e99c8',
#    'baggage': 'Self=1-69237394-561574ca367001726e7d4d60,session.id=2a7eae86-334b-47e6-8b13-39df7492f2c9',
#    'x-amzn-bedrock-agentcore-runtime-session-id': '2a7eae86-334b-47e6-8b13-39df7492f2c9',
#    'x-amzn-trace-id': 'Root=1-69237394-124e2a8957287fdd338dbb12;Parent=b0e6bced537380d0;Sampled=1;Self=1-69237394-561574ca367001726e7d4d60'},
#   'RetryAttempts': 0},
#  'runtimeSessionId': '2a7eae86-334b-47e6-8b13-39df7492f2c9',
#  'traceId': 'Root=1-69237394-124e2a8957287fdd338dbb12;Parent=b0e6bced537380d0;Sampled=1;Self=1-69237394-561574ca367001726e7d4d60',
#  'baggage': 'Self=1-69237394-561574ca367001726e7d4d60,session.id=2a7eae86-334b-47e6-8b13-39df7492f2c9',
#  'contentType': 'application/json',
#  'statusCode': 200,
#  'response': ['"## Analysis of Your Character Proposal: \\"Stark the Elf\\"\\n\\nThank you for sharing your character concept! I\'ve evaluated it against New World\'s lore and gameplay systems, and I need to provide you with some important feedback:\\n\\n---\\n\\n## **❌ Critical Issues - Does Not Fit New World**\\n\\n### **Lore Conflicts:**\\n\\n**1. No Elves in New World**\\n- New World is set during the **Age of Exploration** (16th-17th century) with a grounded historical fantasy approach\\n- **Only human characters exist** - All players are shipwrecked human survivors from various Earth cultures (European, Asian, African, etc.)\\n- There are no traditional fantasy races (elves, dwarves, orcs) in the game\'s universe\\n- The setting references real historical contexts: Spanish conquistadors, Chinese dynasties, Norse warriors, etc.\\n\\n**2. No Innate Racial Abilities**\\n- Magic in New World comes from **Azoth** (the island\'s mystical energy) and is channeled through **weapons and equipment**, not racial traits\\n- Power is earned through wea',
#   "pon mastery, attribute allocation, and gear - not inherited abilities\\n\\n---\\n\\n### **Gameplay Conflicts:**\\n\\n**1. No Race Selection System**\\n- New World uses a **classless, skill-based system** with no race selection\\n- All characters are human with customizable appearances\\n\\n**2. Balance Issues with 50% Healing Increase**\\n- A passive 50% healing boost would be **severely overpowered** because:\\n  - It bypasses the attribute investment system (Focus stat)\\n  - It would stack multiplicatively with existing gear modifiers\\n  - It would create a mandatory meta (everyone forced to play this race)\\n  - It eliminates build diversity and player choice\\n\\n**3. Healing Already Exists Through Equipment**\\n- **Life Staff** (scales with Focus attribute) - primary healing weapon\\n- **Void Gauntlet** - hybrid damage/healing weapon\\n- Healing power is customized through attribute points and equipment perks\\n\\n---\\n\\n## **✅ Alternative Suggestions That Fit New World:**\\n\\nIf you want a healing-focused character, here'",
#   's how to achieve it within the game\'s systems:\\n\\n### **\\"Stark the Healer\\" - Lore-Friendly Version:**\\n\\n**Background Options:**\\n- A **ship\'s surgeon** who survived the wreck and discovered the Life Staff\\n- A **religious healer/priest** learning to harness Azoth\'s power\\n- An **Arcana scholar** specializing in healing potions and mystical medicine\\n- A **shaman or herbalist** from one of Earth\'s cultures who adapts to Aeternum\'s magic\\n\\n**Gameplay Build:**\\n- Max **Focus attribute** (governs healing power)\\n- Primary weapon: **Life Staff** (Healing & Protector skill trees)\\n- Secondary weapon: **Void Gauntlet** (hybrid support)\\n- Armor: **Light armor** (increased healing output and mana regen)\\n- Gear perks: Stack **Outgoing Healing** modifiers\\n- Crafting: Specialize in **Arcana** for healing potions\\n\\nThis approach gives you a powerful healer while respecting New World\'s design philosophy of **player choice through equipment and skill mastery** rather than locked-in racial bonuses.\\n\\n---\\n\\n## **Fin',
#   'al Recommendation:**\\n\\nYour concept shows great enthusiasm for a support/healer role, but it needs significant revision to fit New World\'s established systems. I\'d encourage you to reimagine \\"Stark\\" as a **human healer with a compelling backstory** who masters the Life Staff and Azoth magic through their journey on Aeternum. This maintains your healing fantasy while aligning with the game\'s lore and balanced gameplay systems.\\n\\nWould you like help developing a lore-friendly backstory for Stark as a human healer?"']}

# %% [markdown]
# # Agent Memory

# %% [markdown]
# Maybe add a diagram here to show where memories are going

# %% [markdown]
# ## Create Memories

# %% [markdown]
# ### Create game analyst's short-term memory

# %%
from botocore.exceptions import ClientError
import os
import boto3
import uuid
import logging
from bedrock_agentcore.memory import MemoryClient

def create_session_memory():
    # Configuration
    logging.basicConfig(
        level=logging.INFO,
        format='%(asctime)s [%(levelname)s] %(name)s: %(message)s'
    )

    logger = logging.getLogger("game-analyst-short-term-memory")
    REGION = os.getenv('AWS_REGION', 'us-west-2') # AWS region for the agent
    memory_client = MemoryClient(region_name=REGION)

    # Create unique identifier for this resource
    unique_id = str(uuid.uuid4())[:8]
    memory_name = f"GameAnalystShortTermMemory_{unique_id}"

    try:
        # Create memory resource without strategies (short-term memory only)
        memory = memory_client.create_memory_and_wait(
            name=memory_name,
            strategies=[],  # No strategies for short-term memory
            description="Short-term memory for AgentCore Runtime agent",
            event_expiry_days=7, # Retention period for short-term memory
        )
        memory_id = memory['id']
        logger.info(f"✅ Created memory: {memory_id}")
        return memory_id
    except ClientError as e:
        logger.info(f"❌ ERROR: {e}")
        if e.response['Error']['Code'] == 'ValidationException' and "already exists" in str(e):
            # If memory already exists, retrieve its ID
            memories = memory_client.list_memories()
            memory_id = next((m['id'] for m in memories if m['id'].startswith(memory_name)), None)
            logger.info(f"Memory already exists. Using existing memory ID: {memory_id}")
    except Exception as e:
        # Show any errors during memory creation
        logger.error(f"❌ ERROR: {e}")
        import traceback
        traceback.print_exc()
        # Cleanup on error - delete the memory if it was partially created
        if 'memory_id' in locals() and memory_id:
            try:
                memory_client.delete_memory_and_wait(memory_id=memory_id)
                logger.info(f"Cleaned up memory: {memory_id}")
            except Exception as cleanup_error:
                logger.error(f"Failed to clean up memory: {cleanup_error}")

# %%
session_memory_id = create_session_memory()

# %% [markdown]
# ### Create specialized agent long-term semantic memories

# %%
from botocore.exceptions import ClientError
import os
import boto3
import uuid
import logging
from bedrock_agentcore.memory import MemoryClient
from bedrock_agentcore.memory.constants import StrategyType

def create_specialist_memories(role):
    # Configuration
    logging.basicConfig(
        level=logging.INFO,
        format='%(asctime)s [%(levelname)s] %(name)s: %(message)s'
    )

    logger = logging.getLogger("project-memory-agent")
    REGION = os.getenv('AWS_REGION', 'us-west-2') # AWS region for the agent
    memory_client = MemoryClient(region_name=REGION)

    # Create unique identifier for this resource
    unique_id = str(uuid.uuid4())[:8]
    memory_name = f"Project_{role}_{unique_id}"
    namespace_prefix = f"project/{role}/"
    namespace = namespace_prefix+"{actorId}/semantic"

    try:
        memory = memory_client.create_memory_and_wait(
            name=memory_name,
            strategies=[{
                StrategyType.SEMANTIC.value: {
                    "name": "ProjectSemantic", 
                    "description": "Stores facts from conversations",
                    "namespaces": [namespace],
                }
            }],
            description="Project specific semantic memory for specialized agents",
            event_expiry_days=90, # Retention period for long-term memory
        )
        memory_id = memory['id']
        logger.info(f"✅ Created memory: {memory_id}")
        return memory_id
    except ClientError as e:
        logger.info(f"❌ ERROR: {e}")
        if e.response['Error']['Code'] == 'ValidationException' and "already exists" in str(e):
            # If memory already exists, retrieve its ID
            memories = memory_client.list_memories()
            memory_id = next((m['id'] for m in memories if m['id'].startswith(memory_name)), None)
            logger.info(f"Memory already exists. Using existing memory ID: {memory_id}")
    except Exception as e:
        # Show any errors during memory creation
        logger.error(f"❌ ERROR: {e}")
        import traceback
        traceback.print_exc()
        # Cleanup on error - delete the memory if it was partially created
        if 'memory_id' in locals() and memory_id:
            try:
                memory_client.delete_memory_and_wait(memory_id=memory_id)
                logger.info(f"Cleaned up memory: {memory_id}")
            except Exception as cleanup_error:
                logger.error(f"Failed to clean up memory: {cleanup_error}")

# %%
gameplay_project_memory_id = create_specialist_memories("gameplay")
lore_project_memory_id = create_specialist_memories("lore")
strategy_project_memory_id = create_specialist_memories("strategy")

# %%
print(gameplay_project_memory_id)
print(lore_project_memory_id)
print(strategy_project_memory_id)

# %% [markdown]
# ### Create game analyst user preferences long-term memories

# %%
from botocore.exceptions import ClientError
import os
import boto3
import uuid
import logging
from bedrock_agentcore.memory import MemoryClient
from bedrock_agentcore.memory.constants import StrategyType


def create_analyst_user_preferences():
    # Configuration
    logging.basicConfig(
        level=logging.INFO,
        format='%(asctime)s [%(levelname)s] %(name)s: %(message)s'
    )

    logger = logging.getLogger("game-analyst-user-prefs")
    REGION = os.getenv('AWS_REGION', 'us-west-2') # AWS region for the agent
    memory_client = MemoryClient(region_name=REGION)

    # Create unique identifier for this resource
    unique_id = str(uuid.uuid4())[:8]
    memory_name = f"GameAnalystUserPrefs_{unique_id}"

    try:
        memory = memory_client.create_memory_and_wait(
            name=memory_name,
            strategies=[{
                StrategyType.USER_PREFERENCE.value: {
                    "name": "CustomerPreferences",
                    "description": "Captures customer preferences and behavior",
                    "namespaces": ["analyst/{actorId}/preferences"],
                }
            }],
            description="Project specific semantic memory for specialized agents",
            event_expiry_days=90, # Retention period for long-term memory
        )
        memory_id = memory['id']
        logger.info(f"✅ Created memory: {memory_id}")
        return memory_id
    except ClientError as e:
        logger.info(f"❌ ERROR: {e}")
        if e.response['Error']['Code'] == 'ValidationException' and "already exists" in str(e):
            # If memory already exists, retrieve its ID
            memories = memory_client.list_memories()
            memory_id = next((m['id'] for m in memories if m['id'].startswith(memory_name)), None)
            logger.info(f"Memory already exists. Using existing memory ID: {memory_id}")
    except Exception as e:
        # Show any errors during memory creation
        logger.error(f"❌ ERROR: {e}")
        import traceback
        traceback.print_exc()
        # Cleanup on error - delete the memory if it was partially created
        if 'memory_id' in locals() and memory_id:
            try:
                memory_client.delete_memory_and_wait(memory_id=memory_id)
                logger.info(f"Cleaned up memory: {memory_id}")
            except Exception as cleanup_error:
                logger.error(f"Failed to clean up memory: {cleanup_error}")

# %%
user_prefs_memory_id = create_analyst_user_preferences()

# %%
print(user_prefs_memory_id)

# %% [markdown]
# ### Create memory hook classes for Strands agents

# %% [markdown]
# look at memories.py

# %% [markdown]
# ### For when you already have memories

# %%
user_prefs_memory_id = "GameAnalystUserPrefs_37d1e66e-Ytm1ni3Db5"
gameplay_project_memory_id = "Project_gameplay_597edeef-XOt1OmF0Zd"
lore_project_memory_id = "Project_lore_78f09820-iidpdZ4wfj"
strategy_project_memory_id = "Project_strategy_3443cbe2-0vOWxMHl4Y"
session_memory_id = "GameAnalystShortTermMemory_6502d2be-wJVopQEE4H"

# %% [markdown]
# ### Update Agent IAM Roles to use memories

# %%
import boto3
import json

def update_agent_iam_roles_for_memories(session_memory_id, gameplay_project_memory_id,lore_project_memory_id, strategy_project_memory_id, user_prefs_memory_id, region="us-west-2"):
    """
    Update IAM roles for gameplay, lore, strategy, and game analyst agents to access memories
    """
    iam_client = boto3.client('iam')
    
    # Agent role names from the notebook
    agent_roles = [
       game_analyst_role_name,
        lore_agent_role_name, 
        strategy_role_name,
        gameplay_role_name
    ]
    
    # Memory policy for all three memory types
    memory_policy = {
        "Version": "2012-10-17",
        "Statement": [
            {
                "Effect": "Allow",
                "Action": [
                    "bedrock-agentcore:GetMemory",
                    "bedrock-agentcore:RetrieveMemoryRecords",
                    "bedrock-agentcore:GetMemoryRecord",
                    "bedrock-agentcore:CreateEvent",
                    "bedrock-agentcore:GetEvent",
                    "bedrock-agentcore:CreateMemory",
                    "bedrock-agentcore:DeleteMemoryRecord",
                    "bedrock-agentcore:DeleteMemory",
                    "bedrock-agentcore:UpdateMemory"
                ],
                "Resource": [
                    f"arn:aws:bedrock-agentcore:{region}:*:memory/{session_memory_id}",
                    f"arn:aws:bedrock-agentcore:{region}:*:memory/{gameplay_project_memory_id}",
                    f"arn:aws:bedrock-agentcore:{region}:*:memory/{lore_project_memory_id}",
                    f"arn:aws:bedrock-agentcore:{region}:*:memory/{strategy_project_memory_id}",
                    f"arn:aws:bedrock-agentcore:{region}:*:memory/{user_prefs_memory_id}"
                ]
            },
            {
                "Effect": "Allow",
                "Action": [
                    "bedrock-agentcore:ListEvents",
                    "bedrock-agentcore:ListMemories",
                    "bedrock-agentcore:ListMemoryRecords",
                    "bedrock-agentcore:ListSessions"
                ],
                "Resource": [
                    "*"
                ]
		    }
        ]
    }
    
    # Update each agent role
    for role_name in agent_roles:
        try:
            iam_client.put_role_policy(
                RoleName=role_name,
                PolicyName="AgentCoreMemoryAccess",
                PolicyDocument=json.dumps(memory_policy)
            )
            print(f"✅ Updated {role_name} with memory access permissions")
        except Exception as e:
            print(f"❌ Failed to update {role_name}: {e}")

# Execute the update
update_agent_iam_roles_for_memories(session_memory_id, gameplay_project_memory_id,lore_project_memory_id, strategy_project_memory_id, user_prefs_memory_id)

# %% [markdown]
# ## Update gameplay agent to use project memory

# %%
# set the current working directory to be the gameplay-agent folder
import os
# os.chdir('strands_agents/gameplay-agent')
os.chdir('./strands-agents-with-memory/gameplay-agent-with-memory')
print(os.getcwd())
# Out:
# /Users/sampatze/Documents/Projects/gitlab/accelerate-game-design-reviews-genai-agents/Agents/basic-strands-agents/game-analyst-agent-basic
# /Users/sampatze/Documents/Projects/gitlab/accelerate-game-design-reviews-genai-agents/Agents/strands-agents-with-memory/gameplay-agent-with-memory

# %%
gameplay_agent_code = f'''
import argparse
import json
from mcp import StdioServerParameters, stdio_client
from strands import Agent, tool
from strands.models import BedrockModel
from strands.tools.mcp import MCPClient
from bedrock_agentcore.runtime import BedrockAgentCoreApp
from strands_tools.agent_core_memory import AgentCoreMemoryToolProvider
from memories import LTMemoryHookProvider
from bedrock_agentcore.memory import MemoryClient


###########################
# MCP Clients             #
###########################

# Configure Bedrock model
bedrock_model = BedrockModel(
    model_id="global.anthropic.claude-sonnet-4-5-20250929-v1:0",
    temperature=0.3,
)

# System prompt for the Gameplay agent
GAMEPLAY_AGENT_PROMPT = """
# New World Gameplay Expert Assistant

## Role Definition
You are an authoritative New World Gameplay Expert specializing in Amazon Game Studios' New World MMORPG. Your purpose is to provide accurate, helpful information about all game mechanics and systems.

## Areas of Expertise
<expertise>
- **Character Development**: Attributes (Strength, Dexterity, Intelligence, Focus), weapon scaling, builds
- **Crafting Systems**: Armoring, Weaponsmithing, Engineering, Arcana, Cooking, Furnishing
- **Gathering & Refining**: Mining, Logging, Harvesting, Fishing, Skinning, Smelting, Woodworking, Leatherworking
- **Faction Systems**: Covenant, Marauders, Syndicate mechanics, territory control, faction missions
- **PvE Content**: Expeditions, elite zones, corrupted breaches, outpost rush
- **Game Mechanics**: Combat systems, perks, gems, optimization strategies, meta builds
</expertise>

## Information Retrieval Protocol
Follow this strict sequence for every query:

1. **FIRST**: Use memory retrieval tools to search for the requested information
   - Query format: [Search terms directly related to user question]
   - Example: If asked about "best strength weapons", search for "strength weapons scaling New World"

2. **Information Processing**:
   - If memory tools return relevant information and information is sufficient → respond using retrieved information
   - If memory tools return no/insufficient information → ONLY THEN use knowledge base tools
   - If using knowledge base, search with specific terms from the user's question

3. **Response Structure**:
   - Clearly indicate source: "Based on stored information..." or "According to the knowledge base..."
   - Provide practical, actionable gameplay advice
   - Include specific game mechanics details when available
   - Format information in an easily digestible way (bullet points for lists, bold for key terms)

## Critical Rules
- NEVER use knowledge base tools without first attempting memory retrieval
- ONLY store memories of factual information retrieved from knowledge base tools
- Do not speculate beyond the information available in your tools
- If information conflicts, prioritize the most recent data
- If you cannot find reliable information, acknowledge limitations rather than guessing

Respond to the user's New World gameplay question with accurate, helpful information following the protocol above. Provide your answer in a clear, concise format without any preamble.
"""

app = BedrockAgentCoreApp()

@app.entrypoint
def gameplay_agent(payload, context):
    """
    Creates and runs a gameplay agent connected to the New World Knowledge Base with memory
    """

    client = MemoryClient(region_name="us-west-2")
    # Knowledge Base MCP Client
    kb_client = MCPClient(
        lambda: stdio_client(
            StdioServerParameters(
                command="uvx", 
                args=["awslabs.bedrock-kb-retrieval-mcp-server@latest"],
                env={{
                    "BEDROCK_KB_RERANKING_ENABLED": "true",
                    "KB_INCLUSION_TAG_KEY": "new-world-design-docs"
                }}
            )

        )
    )
    try:
        # Memory setup
        project_memory_id = "{gameplay_project_memory_id}"
        print(f"Project memory ID: {{project_memory_id}}")

        # Get user id
        # user_id = payload.get("user_id", "default-user")

        # Get project id for user project memory
        project_id = payload.get("project_id", "new-world-aternum")

        # Get session id for short-term memory
        session_id = context.session_id  # Get session_id from context

        # Namepspace for project memory for gameplay agent 
        gameplay_namespace = f"project/gameplay/{{project_id}}/semantic"
        
        # Memory tool provider to retrieve memories
        project_memory_provider = AgentCoreMemoryToolProvider(
            memory_id=project_memory_id,
            actor_id=project_id,
            session_id=session_id,
            namespace=gameplay_namespace
        )

        # Hook provider to link actions to a event in the agent lifecycle
        # This is how we define how the agent will store events in its memory
        project_memory_hooks = LTMemoryHookProvider(project_memory_id, client)
        
        with kb_client:
            # Get tools from KB client and memory
            kb_tools = kb_client.list_tools_sync()
            all_tools = kb_tools + project_memory_provider.tools

            # Create the gameplay agent with memory
            agent = Agent(
                tools=all_tools,
                model=bedrock_model,
                hooks=[project_memory_hooks],
                system_prompt=GAMEPLAY_AGENT_PROMPT,
                state={{"actor_id": project_id, "session_id": session_id}}
            )
            
            user_input = payload.get("prompt")
            print("User input:", user_input)
            response = agent(user_input)
            
            return response.message['content'][0]['text']
            
    except Exception as e:
        print(f"Error: {{e}}")
        return f"error {{e}}"

if __name__ == "__main__":
    app.run()
'''

with open('gameplay_agent.py', 'w') as f:
    f.write(gameplay_agent_code)

# %% [markdown]
# ### Re-launch the gameplay agent runtime

# %%
_, gameplay_agentcore_runtime = configure_runtime("gameplay_agent", gameplay_iam_role, "gameplay_agent.py")
gameplay_launch_result = gameplay_agentcore_runtime.launch(auto_update_on_conflict="true")
gameplay_agent_id = gameplay_launch_result.agent_id
gameplay_agent_arn = gameplay_launch_result.agent_arn

print(gameplay_agent_arn)
# Out:
# Entrypoint parsed: file=/Users/sampatze/Documents/Projects/gitlab/accelerate-game-design-reviews-genai-agents/Agents/strands-agents-with-memory/gameplay-agent-with-memory/gameplay_agent.py, bedrock_agentcore_name=gameplay_agent
# Memory disabled - agent will be stateless
# Configuring BedrockAgentCore agent: gameplay_agent
# Memory disabled
# Network mode: PUBLIC
# Generated .dockerignore
# Generated Dockerfile: Dockerfile
# Generated .dockerignore: /Users/sampatze/Documents/Projects/gitlab/accelerate-game-design-reviews-genai-agents/Agents/strands-agents-with-memory/gameplay-agent-with-memory/.dockerignore
# Setting 'gameplay_agent' as default agent
# Bedrock AgentCore configured: /Users/sampatze/Documents/Projects/gitlab/accelerate-game-design-reviews-genai-agents/Agents/strands-agents-with-memory/gameplay-agent-with-memory/.bedrock_agentcore.yaml
# 🚀 Launching Bedrock AgentCore (cloud mode - RECOMMENDED)...
#    • Deploy Python code directly to runtime
#    • No Docker required (DEFAULT behavior)
#    • Production-ready deployment
#
# 💡 Deployment options:
#    • runtime.launch()                → Cloud (current)
#    • runtime.launch(local=True)      → Local development
# Memory disabled - skipping memory creation
# Starting CodeBuild ARM64 deployment for agent 'gameplay_agent' to account 582048091268 (us-west-2)
# Setting up AWS resources (ECR repository, execution roles)...
# Getting or creating ECR repository for agent: gameplay_agent
# ECR repository available: 582048091268.dkr.ecr.us-west-2.amazonaws.com/bedrock-agentcore-gameplay_agent
# Using execution role from config: arn:aws:iam::582048091268:role/agentcore-gameplay_agent_gbpz6w-role
# Preparing CodeBuild project and uploading source...
# ✅ Reusing existing ECR repository: 582048091268.dkr.ecr.us-west-2.amazonaws.com/bedrock-agentcore-gameplay_agent
# Getting or creating CodeBuild execution role for agent: gameplay_agent
# Role name: AmazonBedrockAgentCoreSDKCodeBuild-us-west-2-d5487252a0
# Reusing existing CodeBuild execution role: arn:aws:iam::582048091268:role/AmazonBedrockAgentCoreSDKCodeBuild-us-west-2-d5487252a0
# Using dockerignore.template with 43 patterns for zip filtering
# Uploaded source to S3: gameplay_agent/source.zip
# Updated CodeBuild project: bedrock-agentcore-gameplay_agent-builder
# Starting CodeBuild build (this may take several minutes)...
# Starting CodeBuild monitoring...
# 🔄 QUEUED started (total: 0s)
# ✅ QUEUED completed in 1.1s
# 🔄 PROVISIONING started (total: 1s)
# ✅ PROVISIONING completed in 7.5s
# 🔄 DOWNLOAD_SOURCE started (total: 9s)
# ✅ DOWNLOAD_SOURCE completed in 1.1s
# 🔄 BUILD started (total: 10s)
# ✅ BUILD completed in 18.1s
# 🔄 POST_BUILD started (total: 28s)
# ✅ POST_BUILD completed in 12.8s
# 🔄 COMPLETED started (total: 41s)
# ✅ COMPLETED completed in 1.1s
# 🎉 CodeBuild completed successfully in 0m 41s
# CodeBuild completed successfully
# CodeBuild project configuration saved
# Deploying to Bedrock AgentCore...
# Agent created/updated: arn:aws:bedrock-agentcore:us-west-2:582048091268:runtime/gameplay_agent-mSw4dwFSj1
# Observability is enabled, configuring Transaction Search...
# CloudWatch Logs resource policy already configured
# X-Ray trace destination already configured
# X-Ray indexing rule already configured
# Transaction Search already fully configured
# 🔍 GenAI Observability Dashboard:
#    https://console.aws.amazon.com/cloudwatch/home?region=us-west-2#gen-ai-observability/agent-core
# Polling for endpoint to be ready...
# Agent endpoint: arn:aws:bedrock-agentcore:us-west-2:582048091268:runtime/gameplay_agent-mSw4dwFSj1/runtime-endpoint/DEFAULT
# Deployment completed successfully - Agent: arn:aws:bedrock-agentcore:us-west-2:582048091268:runtime/gameplay_agent-mSw4dwFSj1
# Built with CodeBuild: bedrock-agentcore-gameplay_agent-builder:7f9447c0-1569-43bc-b4b0-b0396df2b3c3
# Deployed to cloud: arn:aws:bedrock-agentcore:us-west-2:582048091268:runtime/gameplay_agent-mSw4dwFSj1
# ECR image: 582048091268.dkr.ecr.us-west-2.amazonaws.com/bedrock-agentcore-gameplay_agent
# 🔍 Agent logs available at:
#    /aws/bedrock-agentcore/runtimes/gameplay_agent-mSw4dwFSj1-DEFAULT --log-stream-name-prefix "2025/11/21/\[runtime-logs]"
#    /aws/bedrock-agentcore/runtimes/gameplay_agent-mSw4dwFSj1-DEFAULT --log-stream-names "otel-rt-logs"
# 💡 Tail logs with: aws logs tail /aws/bedrock-agentcore/runtimes/gameplay_agent-mSw4dwFSj1-DEFAULT --log-stream-name-prefix "2025/11/21/\[runtime-logs]" --follow
# 💡 Or view recent logs: aws logs tail /aws/bedrock-agentcore/runtimes/gameplay_agent-mSw4dwFSj1-DEFAULT --log-stream-name-prefix "2025/11/21/\[runtime-logs]" --since 1h
# arn:aws:bedrock-agentcore:us-west-2:582048091268:runtime/gameplay_agent-mSw4dwFSj1

# %% [markdown]
# ### Save the gameplay agent ARN to AWS SSM ParameterStore

# %%
import boto3
import time

ssm = boto3.client('ssm')
ssm.put_parameter(
    Name=f'/agents/gameplay_agent_arn',
    Value=gameplay_agent_arn,
    Type='String',
    Overwrite=True
)

# %% [markdown]
# ### Check the updated gameplay agent's endpoint status

# %%
status = check_status(gameplay_agentcore_runtime)
print(status)

# %% [markdown]
# ### Test the updated gameplay agent

# %%
invoke_response = gameplay_agentcore_runtime.invoke({"prompt": "Identify the best weapon combinations for a Dexterity build in New World speceifically geared towards PvP combat.", "user_id": "test-user-126","project_id": "new-world-aternum", "session_id": "test-session-002"})
invoke_response

# %%
invoke_response = gameplay_agentcore_runtime.invoke({"prompt": "What are the best weapon combinations for a Dexterity build in New World speceifically geared towards PvP combat.", "user_id": "test-user-123","project_id": "new-world-aternum", "session_id": "test-session-001"})
invoke_response

# %% [markdown]
# ## Update the lore agent to use project memories

# %%
os.chdir('./strands-agents-with-memory/lore-agent-with-memory')
print(os.getcwd())

# %%
lore_agent_code = f'''
import argparse
import json
from mcp import StdioServerParameters, stdio_client
from strands import Agent, tool
from strands.models import BedrockModel
from strands.tools.mcp import MCPClient
from bedrock_agentcore.runtime import BedrockAgentCoreApp
from strands_tools.agent_core_memory import AgentCoreMemoryToolProvider
from memories import LTMemoryHookProvider
from bedrock_agentcore.memory import MemoryClient

###########################
# MCP Clients             #
###########################

# Configure Bedrock model
bedrock_model = BedrockModel(
    model_id="global.anthropic.claude-sonnet-4-5-20250929-v1:0",
    temperature=0.3,
)

# System prompt for the Knowledge Base agent
LORE_AGENT_PROMPT = """
# New World Game Lore Expert

<role>
You are an authoritative Game Analyst specializing in the lore and world-building of "New World," the MMORPG developed by Amazon Game Studios. Your purpose is to provide accurate, comprehensive information about the game's narrative elements, history, and world.
</role>

- Complete understanding of New World's core storyline, main objectives, and narrative arcs
- Detailed knowledge of Aeternum's history, mythology, and underlying lore
- Comprehensive information about locations, geographical features, settlements, and territories
- Familiarity with key characters, factions, and demographic groups within the game world
</expertise>

<information_retrieval_protocol>
When responding to any user query about New World lore, strictly follow this sequence:

1. **MEMORY RETRIEVAL (MANDATORY FIRST STEP)**
   - Search your memory using specific terms directly related to the user's question
   - Example search format: [Aeternum origin] [Angry Earth faction] [Great Cleave history]

2. **INFORMATION PROCESSING**
   - If memory tools return relevant information and information is sufficient → respond using retrieved information
   - If memory retrieval yields insufficient or no information → ONLY THEN access your knowledge base
   - When using knowledge base, search with precise terms from the user's question

3. **SOURCE ATTRIBUTION**
   - Clearly indicate your information source in your response:
     * "Based on stored information..." (when using memory)
     * "According to the knowledge base..." (when using knowledge base)
</information_retrieval_protocol>

<response_guidelines>
- Present information in a structured, easily digestible format
- Use **bold formatting** for key terms, locations, and character names
- Organize lists and multiple points using bullet points
- Include specific in-game details when available
- Provide context that helps players understand the narrative significance
</response_guidelines>

<critical_rules>
- NEVER access knowledge base without first attempting memory retrieval
- Only store factual information retrieved from knowledge base tools as memories
- Do not speculate or invent lore beyond what's available in your tools
- When information conflicts, prioritize the most recent or most authoritative source
- If you cannot find reliable information on a topic, acknowledge these limitations rather than guessing
</critical_rules>

When a user asks about New World lore, respond with accurate, helpful information following this protocol. Your answer should be clear, concise, and directly address the user's question without any unnecessary preamble.
"""
app = BedrockAgentCoreApp()
# Create and run the Knowledge Base agent
@app.entrypoint
def lore_agent(payload, context):
    """
    Creates and runs an agent connected to the Knowledge Base
    """
    # Knowledge Base MCP Client
    kb_client = MCPClient(
        lambda: stdio_client(
            StdioServerParameters(
                command="uvx", 
                args=["awslabs.bedrock-kb-retrieval-mcp-server@latest"],
                env={{
                    "BEDROCK_KB_RERANKING_ENABLED": "true",
                    "KB_INCLUSION_TAG_KEY": "new-world-design-docs"
                }}
            )

        )
    )

    # Initialize the memory client
    client = MemoryClient(region_name="us-west-2")

    try:
        # Memory setup
        project_memory_id = "{lore_project_memory_id}"
        print(f"Project memory ID: {{project_memory_id}}")
        user_id = payload.get("user_id", "default-user")
        project_id = payload.get("project_id", "new-world-aternum")
        session_id = context.session_id
        lore_namespace = f"project/{{project_id}}/semantic"
        
        # Memory tool provider to retrieve memories
        project_memory_provider = AgentCoreMemoryToolProvider(
            memory_id=project_memory_id,
            actor_id=project_id,
            session_id=session_id,
            namespace=lore_namespace
        )

        # Hook provider to save memories
        project_memory_hooks = LTMemoryHookProvider(project_memory_id, client)

        with kb_client:
            # Get tools from the KB client
            kb_tools = kb_client.list_tools_sync()
            
            all_tools = kb_tools + project_memory_provider.tools

            # Create the gameplay agent with memory
            agent = Agent(
                tools=all_tools,
                model=bedrock_model,
                hooks=[project_memory_hooks],
                system_prompt=LORE_AGENT_PROMPT,
                state={{"actor_id": project_id, "session_id": session_id}}
            )
            
            user_input = payload.get("prompt")
            print("User input:", user_input)
            response = agent(user_input)
            return response.message['content'][0]['text']
        
                    
    except Exception as e:
        print(f"Error accessing Knowledge Base: {{e}}")
        return f"error {{e}}"

if __name__ == "__main__":
    app.run()
'''

with open('lore_agent.py', 'w') as f:
    f.write(lore_agent_code)

# %% [markdown]
# ### Re-launch the lore agent runtime

# %%
_, lore_agentcore_runtime = configure_runtime("lore_agent", lore_agent_iam_role, "lore_agent.py")
lore_launch_result = lore_agentcore_runtime.launch(auto_update_on_conflict="true")
lore_agent_id = lore_launch_result.agent_id
lore_agent_arn = lore_launch_result.agent_arn

print(lore_agent_arn)

# %% [markdown]
# ### Save the agent ARN to AWS SSM ParameterStore

# %%
import time

ssm = boto3.client('ssm')
ssm.put_parameter(
    Name=f'/agents/lore_agent_arn',
    Value=lore_agent_arn,
    Type='String',
    Overwrite=True
)

# %% [markdown]
# ### Check the updated lore agent's endpoint status

# %%
status = check_status(lore_agentcore_runtime)
print(status)

# %% [markdown]
# ### Test the updated lore agent

# %%
invoke_response = lore_agentcore_runtime.invoke({"prompt": "How did the Angry Earth come to be, and what is their relationship with the island's natural Azoth energy?", "user_id": "test-user-125","project_id": "new-world-aternum", "session_id": "test-session-005"})
invoke_response

# %%
invoke_response = lore_agentcore_runtime.invoke({"prompt": "How did the Angry Earth come to be?", "user_id": "test-user-128","project_id": "new-world-aternum", "session_id": "test-session-009"})
invoke_response

# %% [markdown]
# ## Update the strategy agent to use project memories

# %%
os.chdir('./strands-agents-with-memory/strategy-agent-with-memory')
print(os.getcwd())

# %%
strategy_agent_code = f'''
import argparse
import json
from mcp import StdioServerParameters, stdio_client
from strands import Agent, tool
from strands.models import BedrockModel
from strands.tools.mcp import MCPClient
from bedrock_agentcore.runtime import BedrockAgentCoreApp
from strands_tools.agent_core_memory import AgentCoreMemoryToolProvider
from memories import LTMemoryHookProvider
from bedrock_agentcore.memory import MemoryClient

###########################
# MCP Clients             #
###########################

# Configure Bedrock model
bedrock_model = BedrockModel(
    model_id="global.anthropic.claude-sonnet-4-5-20250929-v1:0",
    temperature=0.3,
)

# System prompt for the Knowledge Base agent
STRATEGY_AGENT_PROMPT = """
You are a business strategy expert at Amazon Game Studios. Your expertise includes:
- Game industry market analysis and competitive positioning
- Player acquisition, retention, and monetization strategies
- Product portfolio management and roadmap planning
- Performance metrics analysis and strategic recommendations
- Resource allocation and investment prioritization
- Company priorities and roadmaps


You have access to a knowledge base containing corporate strategy documents of Amazon Game Studios. ALWAYS use the available knowledge base tools to retrieve information before answering questions. If the knowledge base returns relevant information, use that information in your response.

When using knowledge base tools, make sure to:
1. Use the exact query or related terms to search the knowledge base
2. Include the retrieved information in your response
3. Only use information from the knowledge base
"""
app = BedrockAgentCoreApp()
# Create and run the Knowledge Base agent
@app.entrypoint
def strategy_agent(payload, context):
    """
    Creates and runs an agent connected to the Knowledge Base
    """
    # Knowledge Base MCP Client
    kb_client = MCPClient(
        lambda: stdio_client(
            StdioServerParameters(
                command="uvx", 
                args=["awslabs.bedrock-kb-retrieval-mcp-server@latest"],
                env={{
                    "BEDROCK_KB_RERANKING_ENABLED": "true",
                    "KB_INCLUSION_TAG_KEY": "strategy-docs"
                }}
            )

        )
)

    # Initialize the memory client
    client = MemoryClient(region_name="us-west-2")

    try:
        # Memory setup
        project_memory_id = "{strategy_project_memory_id}"
        print(f"Project memory ID: {{project_memory_id}}")
        user_id = payload.get("user_id", "default-user")
        project_id = payload.get("project_id", "new-world-aternum")
        session_id = context.session_id
        strategy_namespace = f"project/{{project_id}}/semantic"
        
        # Memory tool provider to retrieve memories
        project_memory_provider = AgentCoreMemoryToolProvider(
            memory_id=project_memory_id,
            actor_id=project_id,
            session_id=session_id,
            namespace=strategy_namespace
        )

        # Hook provider to save memories
        project_memory_hooks = LTMemoryHookProvider(project_memory_id, client)

        with kb_client:
            # Get tools from the KB client
            kb_tools = kb_client.list_tools_sync()
            
            all_tools = kb_tools + project_memory_provider.tools

            # Create the gameplay agent with memory
            agent = Agent(
                tools=all_tools,
                model=bedrock_model,
                hooks=[project_memory_hooks],
                system_prompt=STRATEGY_AGENT_PROMPT,
                state={{"actor_id": project_id, "session_id": session_id}}
            )
            
            user_input = payload.get("prompt")
            print("User input:", user_input)
            response = agent(user_input)
            return response.message['content'][0]['text']
        
                    
    except Exception as e:
        print(f"Error accessing Knowledge Base: {{e}}")
        return f"error {{e}}"

if __name__ == "__main__":
    app.run()
'''

with open('strategy_agent.py', 'w') as f:
    f.write(strategy_agent_code)

# %% [markdown]
# ### Re-Launch the srategy agent runtime

# %%
_, strategy_agentcore_runtime = configure_runtime("strategy_agent", strategy_iam_role, "strategy_agent.py")
strategy_launch_result = strategy_agentcore_runtime.launch(auto_update_on_conflict="true")
strategy_agent_id = strategy_launch_result.agent_id
strategy_agent_arn = strategy_launch_result.agent_arn

print(strategy_agent_arn)

# %% [markdown]
# ### Save the agent ARN to AWS SSM ParameterStore

# %%
import time

ssm = boto3.client('ssm')
ssm.put_parameter(
    Name=f'/agents/strategy_agent_arn',
    Value=strategy_agent_arn,
    Type='String',
    Overwrite=True
)

# %% [markdown]
# ### Check the updated strategy agent's endpoint status

# %%
status = check_status(strategy_agentcore_runtime)
print(status)

# %% [markdown]
# ### Test the updated strategy agent

# %%
invoke_response = strategy_agentcore_runtime.invoke({"prompt": "What is the main goal for new characters for 2026?", "user_id": "test-user-128","project_id": "new-world-aternum", "session_id": "test-session-009"})
invoke_response

# %% [markdown]
# ## Update game analyst agent to include all user preferences and session memories

# %%
os.chdir('./strands-agents-with-memory/game-analyst-agent-with-memory')
print(os.getcwd())

# %%
game_analyst_agent_code = f'''

import os
import json
import logging
import boto3
from typing import Dict, Any
from strands import Agent, tool
from strands.models import BedrockModel
from bedrock_agentcore.memory import MemoryClient
from bedrock_agentcore.runtime import BedrockAgentCoreApp
from strands.hooks import AgentInitializedEvent, HookProvider, HookRegistry, MessageAddedEvent
from invoke_agent_utils import invoke_agent_with_boto3
from memories import ShortTermMemoryHook as STM, LTMemoryHookProvider as LTM
from strands_tools.agent_core_memory import AgentCoreMemoryToolProvider

# Configure detailed logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s [%(levelname)s] %(name)s: %(message)s'
)
logger = logging.getLogger("game-analyst-agent")

# Initialize the agent core app
app = BedrockAgentCoreApp()

# Configure Bedrock model
bedrock_model = BedrockModel(
    model_id="global.anthropic.claude-sonnet-4-5-20250929-v1:0",
    temperature=0.3,
)


# System prompt for the Game Analyst agent
GAME_ANALYST_PROMPT = """
# Game Analyst Agent

## Role and Expertise
You are a professional Game Analyst Agent specializing in analyzing game design documents for New World Aeternum (also known as New World). Your expertise includes understanding the game's story, lore, gameplay mechanics, and overall design philosophy.

## Primary Objectives
- Review game design documentation thoroughly
- Understand the developer's vision and intentions
- Provide expert feedback with insightful analysis
- Offer constructive recommendations that maintain consistency with the game's established elements
- Remember user preferences from previous interactions in the same session

## Available Tools
You have access to specialized tools to enhance your analysis:

<tool_lore>
**Lore Agent Tool**
Use this tool for queries about the game world, story, and lore:
- Narrative consistency and world-building evaluation
- Character development analysis
- Thematic elements and story structure assessment
- Fictional histories and setting coherence verification
- Identification of opportunities for deeper player immersion
</tool_lore>

<tool_gameplay>
**Gameplay Agent Tool**
Use this tool for queries about game mechanics and gameplay systems:
- Game systems, mechanics, and balance analysis
- Core gameplay loops and progression systems evaluation
- Player motivation and engagement assessment
- Difficulty curves, skill ceilings, and accessibility considerations
- Identification of potential balance issues and optimization opportunities
</tool_gameplay>

<tool_strategy>
**Corporate Strategy Agent Tool**
For queries around corporate strategy, performance metrics, roadmaps, and strategic priorities use strategy_agent tool:
    - Specializes in corporate strategy, performance metrics, and strategic priorities
    - Analyzes corporate strategy, performance metrics, and strategic priorities
    - Evaluates corporate strategy, performance metrics, and strategic priorities
    - Identifies opportunities for improvement in corporate strategy, performance metrics, and strategic priorities
</tool_strategy>

## Memory Functionality
You can recall previous interactions across sessions within the previous 7 days. Always refer to your memory regarding user preferences for formatting your responses and their specific interests or concerns about their game design. You may refer to previously saved memories on session data to answer questions.

## Response Guidelines
1. Analyze the submitted game design document thoroughly
2. Maintain consistency with New World's established story, lore, and gameplay
3. Provide specific, actionable feedback rather than general statements
4. Format your response according to previously established user preferences

When responding to queries, provide your analysis directly without preambles or additional explanations beyond what was requested.
"""

def get_agent_arn(agent_name: str) -> str:
    """
    Retrieve agent ARN from Parameter Store
    """
    try:
        ssm = boto3.client('ssm')
        response = ssm.get_parameter(
            Name=f'/agents/{{agent_name}}_arn'
        )
        return response['Parameter']['Value']
    except Exception as err:
        print(err)
        raise err

@tool
def get_lore_agent(payload):
    """
    Call the lore agent tool to get information about the game lore.
    """
    try:
        lore_agent_arn = get_agent_arn("lore_agent")
        result = invoke_agent_with_boto3(lore_agent_arn, user_query=payload)
    except Exception as e:
        result = str(e)
        logger.exception("Exception calling lore agent: ")
    return result

@tool
def get_gameplay_agent(payload):
    """
    Call the lore agent tool to get information about the game lore.
    """
    try:
        gameplay_agent_arn = get_agent_arn("gameplay_agent")
        result = invoke_agent_with_boto3(gameplay_agent_arn, user_query=payload)
    except Exception as e:
        result = str(e)
        logger.exception("Exception calling gameplay agent: ")
    return result

@tool
def get_strategy_agent(payload):
    """
    Call the strategy agent tool to get information about the company's corporate strategy.
    """
    try:
        strategy_agent_arn = get_agent_arn("strategy_agent")
        result = invoke_agent_with_boto3(strategy_agent_arn, user_query=payload)
    except Exception as e:
        result = str(e)
        logger.exception("Exception calling gameplay agent: ")
    return result

agent = None 

@app.entrypoint
async def game_analyst_agent(payload, context):
    global agent
    
    # Log both payload and context info
    logger.info(f"Received payload: {{payload}}")
    logger.info(f"Context session_id: {{context.session_id}}")
    # Extract and validate required values
    user_input = payload.get("prompt")
    user_id = payload.get("user_id")  # Provide default for demo
    project_id = payload.get("project_id")  # Provide default for demo
    session_id = context.session_id  # Get session_id from context
    
    client = MemoryClient(region_name="us-west-2")
    # Validate required fields
    if user_input is None:
        error_msg = "❌ ERROR: Missing 'prompt' field in payload"
        logger.error(error_msg)
        return error_msg
    
    # Initialize agent on first request with short-term memories
    if agent is None:
        logger.info("First request - initializing agent")
        try:
            # Memory setup
            user_prefs_memory_id = "{user_prefs_memory_id}"
            user_prefs_namespace = f"user/{{user_id}}/preferences"

            # Memory tool provider
            user_prefs_memory_provider = AgentCoreMemoryToolProvider(
                memory_id=user_prefs_memory_id,
                actor_id=user_id,
                session_id=session_id,
                namespace=user_prefs_namespace
            )
            session_memory_id = "{session_memory_id}"

            user_prefs_memory_hooks = LTM(user_prefs_memory_id, client)

            session_memory_hooks = STM(client, session_memory_id)

            logger.info(f"Initializing agent for actor_id={{user_id}}, project_id={{project_id}}, session_id={{session_id}}")

            agent = Agent(
                tools=[get_gameplay_agent, get_lore_agent, get_strategy_agent, user_prefs_memory_provider.tools],
                model=bedrock_model,
                hooks=[user_prefs_memory_hooks, session_memory_hooks],
                system_prompt=GAME_ANALYST_PROMPT,
                state={{"actor_id": user_id, "session_id": session_id}}
            )
        except Exception as e:
            logger.exception("Exception initializing agent: ")
            return f"error {{e}}"

    else:
        logger.info("Using existing agent instance")
        # Update the session ID in case it changed
        if agent.state.get("session_id") != session_id:
            logger.info(f"Updating session ID to {{session_id}}")
            agent.state.set("session_id", session_id)
        if agent.state.get("user_id") != user_id:
            logger.info(f"Updating user ID to {{user_id}}")
            agent.state.set("user_id", user_id)
        if agent.state.get("project_id") != project_id:
            logger.info(f"Updating project ID to {{project_id}}")
            agent.state.set("project_id", project_id)
    # Invoke the agent with the user's input
    logger.info(f"Invoking agent with input: {{user_input}}")
    
    # Send request to necessary agents same as before
    try:

        response = agent(user_input)
        return response.message['content'][0]['text']
        
                    
    except Exception as e:
        print(f"Error in orchestrator agent: {{e}}")
        return f"error {{e}}"
    
    # try:
    #     # Stream each chunk as it becomes available
    #     async for event in agent.stream_async(user_input):
    #         if "data" in event:
    #             yield event["data"]
            
    # except Exception as e:
    #     # Handle errors gracefully in streaming context
    #     error_response = {{"error": str(e), "type": "stream_error"}}
    #     print(f"Streaming error: {{error_response}}")
    #     yield error_response
    

if __name__ == "__main__":
    app.run()
'''

with open('game_analyst_agent.py', 'w') as f:
    f.write(game_analyst_agent_code)

# %% [markdown]
# ### Re-launch the updated game analyst agent runtime

# %%
_, game_analyst_agentcore_runtime = configure_runtime("game_analyst_agent", game_analyst_iam_role, "game_analyst_agent.py")
game_analyst_launch_result = game_analyst_agentcore_runtime.launch(auto_update_on_conflict="true")

# %% [markdown]
# ### Check the updated game analyst agent's endpoint status

# %%
status = check_status(game_analyst_agentcore_runtime)
print(status)

# %% [markdown]
# ### Test the updated game analyst agent

# %%
import uuid
test_session_id = "test-session-12345676809453903427"

# Send our first message
invoke_response = game_analyst_agentcore_runtime.invoke(
    {
        "prompt": "I want to introduce a portal system where users can talk to a witch and learn how to create portals. These portals can teleport them to any location that they have already been to",
        "project_id": "new-world-aternum",
        "user_id": "test_user_129"
    }, 
    session_id=test_session_id
)

invoke_response

# %%
import uuid
test_session_id = "test-session-12345676809453903827"

# Send our first message
invoke_response = game_analyst_agentcore_runtime.invoke(
    {
        "prompt": "Hello",
        "project_id": "new-world-aternum",
        "user_id": "test_user_120"
    }, 
    session_id=test_session_id
)
invoke_response

# %%
import uuid
test_session_id = "test-session-12345676809453903827"

# Send our first message
invoke_response = game_analyst_agentcore_runtime.invoke(
    {
        "prompt": "I want to introduce a portal system where users can talk to a witch and learn how to create portals. These portals can teleport them to a robot world where they can master a new high tech weapon mastery tree.",
        "project_id": "new-world-aternum",
        "user_id": "test_user_120"
    }, 
    session_id=test_session_id
)

invoke_response

# %%
import uuid
test_session_id = "test-session-12345676809453903827"

# Send our first message
invoke_response = game_analyst_agentcore_runtime.invoke(
    {
        "prompt": "What if I made the world the portals led to instead a land of elves?",
        "project_id": "new-world-aternum",
        "user_id": "test_user_120"
    }, 
    session_id=test_session_id
)

invoke_response

# %%
import uuid
test_session_id = "test-session-12345676809453900499"

# Send our first message
invoke_response = game_analyst_agentcore_runtime.invoke(
    {
        "prompt": "Proposing a new item called the holy grail where if it is found the player is resistent to any damage for 30 seconds when the item is activated. It can only be activated once per raid.",
        "project_id": "new-world-aternum",
        "user_id": "test_user_189"
    }, 
    session_id=test_session_id
)

invoke_response

# %%
import uuid
test_session_id = "test-session-12345676809453903410"

# Send our first message
invoke_response = game_analyst_agentcore_runtime.invoke(
    {
        "prompt": "A portal system that is summoned by an ancient that you meet up in a mountain. They think you stole their precious stone so they send you through the portal to a mystical realm that you must find a way to escape.",
        "project_id": "new-world-aternum",
        "user_id": "test_user_139"
    }, 
    session_id=test_session_id
)

invoke_response

# %% [markdown]
# # Let's see this in action in our project management tool

# %% [markdown]
# # Observability

# %% [markdown]
# Quickly show the traces from the Game Analyst execution

# %% [markdown]
# ## UI Design

# %% [markdown]
# - Project management site
# - Feedback area collaboration across teams and analysts
# - each project has memories rather than just user memory
# - User preferences are the analyst's preferences
# - could have it as a game perspective, project perspective, user perspective
